# %% [markdown]
# <a href="https://colab.research.google.com/github/NarawitPrathansap/BasicProg_DataViz65/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Meta Data = Dara that describe data

# %% [markdown]
# ## CSV = Comma Separated Value

# %% [markdown]
# # นำ Data เข้า
# *   upload to colab
# *   link with google drive

# %% [markdown]
# ### upload to colab

# %%
data0 = pd.read_csv('/content/opendata_project.csv')

# %%
data0.head()
# Out:
#    row_number                project_id                             name_en  \
# 0      7880.0  5ee08d64dda791001299b2a6  Winning Residence Sukhumvit Praksa
# 1     16689.0             project_11326                    Gift Condominium
# 2       290.0  62739c4089233e001362b001    Sanrak 9 Sukprayoon Nong Krathum
# 3     20719.0              project_2010                     Baan Sansabai 1
# 4       199.0             project_16838          Baanpruksa Ratchapruek-345
#
#                               name_th propertytype_id propertytype_name_en  \
# 0  วินนิ่ง เรสซิเดนท์ สุขุมวิท แพรกษา               1       Detached House
# 1                 กิ๊ฟท์ คอนโดมิเนียม               2                Condo
# 2      แสนรัก 9 ศุขประยูร หนองกระทุ่ม               3             Townhome
# 3                       บ้านแสนสบาย 1               1       Detached House
# 4              บ้านพฤกษา ราชพฤกษ์-345               3             Townhome
#
#   propertytype_name_th price_min     developer_id  \
# 0                 บ้าน   3790000  developer_10678
# 1                คอนโด   1100000   developer_7319
# 2             ทาวน์โฮม         0  developer_10510
# 3                 บ้าน         0  developer_10510
# 4             ทาวน์โฮม   1930000   developer_1026
#
#               developer_name_en  ... facility_meeting  facility_park  \
# 0  Winning Asset Plus Co., Ltd.  ...              NaN            NaN
# 1      Gift Asset Land Co.,Ltd.  ...              NaN            1.0
# 2                           NaN  ...              NaN            NaN
# 3                           NaN  ...              NaN            NaN
# 4  Preuksa Real Estate Co.,Ltd.  ...              NaN            1.0
#
#    facility_playground facility_pool facility_security      date_created  \
# 0                  NaN           1.0               1.0   10/6/2020 14:36
# 1                  NaN           1.0               1.0  30/10/2017 15:38
# 2                  NaN           NaN               NaN    5/5/2022 16:43
# 3                  NaN           NaN               NaN    5/9/2016 15:32
# 4                  NaN           1.0               1.0    5/9/2019 11:49
#
#      date_finish     date_updated  source  \
# 0            NaN  4/12/2020 10:32  baania
# 1  1/1/2013 7:00  4/12/2020 10:49  baania
# 2            NaN   5/5/2022 17:30  baania
# 3  2/1/1970 7:00  4/12/2020 10:45  baania
# 4  2/1/1970 7:00  17/3/2021 12:00  baania
#
#                                          url_project
# 0  https://baania.com/th/project/วินนิ่ง-เรสซิเดน...
# 1  https://baania.com/th/project/กิ๊ฟท์-คอนโดมิเน...
# 2  https://baania.com/th/project/แสนรัก-9-ศุขประย...
# 3  https://baania.com/th/project/บ้านแสนสบาย-1-pr...
# 4  https://baania.com/th/project/บ้านพฤกษา-ราชพฤก...
#
# [5 rows x 45 columns]

# %% [markdown]
# ### link with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1 = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')

# %%
data1.head()
# Out:
#    row_number     unittype_id    project_id             name_th  \
# 0       27501   unittype_9565  project_2446           2 Bedroom
# 1       28777  unittype_10267  project_3543  บ้านแฝดสองชั้น Z-2
# 2       28865    unittype_471   project_143    1 Bedroom Type B
# 3       24988  unittype_19506  project_7766    Studio Floor 1-2
# 4       38596  unittype_10290  project_3551                TH 3
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                2                Condo                คอนโด
# 1            20000           Twin house              บ้านแฝด
# 2                2                Condo                คอนโด
# 3                2                Condo                คอนโด
# 4                3             Townhome             ทาวน์โฮม
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN             37.3  2500000.0  ...               1.0
# 1               40.0            150.0  2390000.0  ...               NaN
# 2                NaN             28.0        NaN  ...               NaN
# 3                NaN             27.0   170000.0  ...               NaN
# 4                NaN            182.0  2390000.0  ...               1.0
#
#    count_room_kitchen  count_room_living  count_room_maid  count_room_storage  \
# 0                 1.0                NaN              NaN                 NaN
# 1                 NaN                NaN              NaN                 NaN
# 2                 NaN                NaN              NaN                 NaN
# 3                 NaN                NaN              NaN                 NaN
# 4                 1.0                NaN              NaN                 2.0
#
#    count_room_utility      date_created      date_updated  source  \
# 0                 NaN  19/11/2021 18:00  19/11/2021 17:44  baania
# 1                 NaN   27/1/2022 14:30   27/1/2022 14:22  baania
# 2                 NaN   14/1/2022 15:00   14/1/2022 14:40  baania
# 3                 NaN   4/12/2020 10:40   14/10/2020 1:06  baania
# 4                 NaN  12/11/2021 13:30    3/2/2021 12:12  baania
#
#                                         url_unittype
# 0  https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 1  https://baania.com/th/project/เซน-บาย-ศิวาลัย-...
# 2  https://baania.com/th/project/วันพลัส-นายน์ทีน...
# 3  https://baania.com/th/project/บ้านสวนชมน้ำ-776...
# 4  https://baania.com/th/project/เบล็สทาวน์-ศรีนค...
#
# [5 rows x 27 columns]

# %%
data1.tail(10)
# Out:
#        row_number               unittype_id                project_id  \
# 42615       36172            unittype_34140             project_14663
# 42616       28981            unittype_25373             project_10133
# 42617       35109             unittype_1459               project_711
# 42618       22299            unittype_13674              project_5356
# 42619       11944            unittype_34884             project_15005
# 42620       37109            unittype_38508             project_16864
# 42621          14            unittype_14016              project_5275
# 42622       41009  617bde1687dd2300149d2195  617bdd47f62011001350de07
# 42623        9333            unittype_37375             project_16389
# 42624         780            unittype_17011              project_6762
#
#                    name_th  propertytype_id propertytype_name_en  \
# 42615            2 Bedroom                2                Condo
# 42616    บ้านเดี่ยวสองชั้น                1       Detached House
# 42617          บ้านแสงรุ่ง                3             Townhome
# 42618  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 42619             Ametrine                1       Detached House
# 42620               Canola                1       Detached House
# 42621             Grandeur                1       Detached House
# 42622               Grande                3             Townhome
# 42623  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 42624             บ้านธารา                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 42615                คอนโด                NaN             60.0   3500000.0
# 42616                 บ้าน                NaN            200.0         NaN
# 42617             ทาวน์โฮม                NaN              NaN         NaN
# 42618                 บ้าน                NaN            130.0  36500000.0
# 42619                 บ้าน                NaN            353.0  23590000.0
# 42620                 บ้าน                NaN            157.0         NaN
# 42621                 บ้าน                NaN            223.0   7490000.0
# 42622             ทาวน์โฮม                NaN            133.0         NaN
# 42623                 บ้าน                NaN            180.0   3200000.0
# 42624                 บ้าน                NaN            170.0   3790000.0
#
#        ...  count_room_guest  count_room_kitchen  count_room_living  \
# 42615  ...               1.0                 NaN                NaN
# 42616  ...               1.0                 1.0                NaN
# 42617  ...               NaN                 NaN                NaN
# 42618  ...               NaN                 NaN                1.0
# 42619  ...               1.0                 1.0                1.0
# 42620  ...               NaN                 1.0                NaN
# 42621  ...               NaN                 NaN                NaN
# 42622  ...               1.0                 NaN                NaN
# 42623  ...               NaN                 1.0                NaN
# 42624  ...               1.0                 1.0                NaN
#
#        count_room_maid  count_room_storage  count_room_utility  \
# 42615              NaN                 NaN                 NaN
# 42616              NaN                 1.0                 NaN
# 42617              NaN                 NaN                 NaN
# 42618              NaN                 NaN                 NaN
# 42619              1.0                 1.0                 NaN
# 42620              NaN                 NaN                 NaN
# 42621              NaN                 NaN                 NaN
# 42622              NaN                 NaN                 NaN
# 42623              NaN                 NaN                 NaN
# 42624              NaN                 NaN                 NaN
#
#            date_created      date_updated  source  \
# 42615   28/2/2022 15:30   28/2/2022 14:43  baania
# 42616  12/11/2021 13:20   14/10/2020 0:49  baania
# 42617   4/12/2020 10:36   14/10/2020 0:39  baania
# 42618   4/12/2020 10:38   14/10/2020 0:47  baania
# 42619     3/6/2022 1:00     3/6/2022 0:51  baania
# 42620  12/11/2021 13:22  14/10/2020 10:05  baania
# 42621   4/12/2020 10:36   14/10/2020 0:37  baania
# 42622  12/11/2021 13:34  29/10/2021 18:43  baania
# 42623   4/12/2020 10:42  14/10/2020 19:30  baania
# 42624  12/11/2021 13:19   14/10/2020 0:41  baania
#
#                                             url_unittype
# 42615  https://baania.com/th/project/พลัส-คอนโด-โคราช...
# 42616  https://baania.com/th/project/ระยองการ์เด้นฮิล...
# 42617  https://baania.com/th/project/บ้านแสงรุ่ง-711/...
# 42618  https://baania.com/th/project/บ้านศุธาวัลย์-53...
# 42619  https://baania.com/th/project/เศรษฐสิริ-แจ้งวั...
# 42620  https://baania.com/th/project/อิคอนเนเจอร์-พระ...
# 42621  https://baania.com/th/project/คาซ่า-วิลล์-ราชพ...
# 42622  https://baania.com/th/project/เดอะริคโค้-ทาวน์...
# 42623  https://baania.com/th/project/ณรงค์กิจ-รามอินท...
# 42624  https://baania.com/th/project/วราสิริ-รังสิต-ด...
#
# [10 rows x 27 columns]

# %%
data1.shape
# Out:
# (42625, 27)

# %%
data1.describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count  42625.000000     42625.000000        3747.000000     36999.000000
# mean   21313.000000       938.471859          44.413819       139.286943
# std    12304.921949      4220.823322          21.502884       111.939963
# min        1.000000         1.000000           1.000000        14.000000
# 25%    10657.000000         1.000000          23.000000        60.000000
# 50%    21313.000000         2.000000          50.000000       125.000000
# 75%    31969.000000         3.000000          60.000000       179.000000
# max    42625.000000     20000.000000         335.000000      4350.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.542800e+04           1780.000000             0.0
# mean   5.569699e+06              2.465730             NaN
# std    1.117088e+07              1.512717             NaN
# min    1.000000e+05              1.000000             NaN
# 25%    1.950000e+06              1.000000             NaN
# 50%    3.100000e+06              2.000000             NaN
# 75%    5.290000e+06              3.000000             NaN
# max    5.800000e+08             10.000000             NaN
#
#        count_floor_internal  count_parking  count_room_bath  count_room_bed  \
# count          29709.000000   23520.000000     41144.000000    40658.000000
# mean               1.945572       1.844090         2.286263        2.528137
# std                0.658217       0.759404         1.145901        1.158793
# min                0.000000       1.000000         0.000000        0.000000
# 25%                2.000000       1.000000         1.000000        2.000000
# 50%                2.000000       2.000000         2.000000        3.000000
# 75%                2.000000       2.000000         3.000000        3.000000
# max                9.000000      10.000000        11.000000       10.000000
#
#        count_room_dinning  count_room_guest  count_room_kitchen  \
# count        13670.000000      13044.000000        20454.000000
# mean             1.001902          1.010810            1.018138
# std              0.043572          0.106334            0.134549
# min              1.000000          1.000000            1.000000
# 25%              1.000000          1.000000            1.000000
# 50%              1.000000          1.000000            1.000000
# 75%              1.000000          1.000000            1.000000
# max              2.000000          3.000000            3.000000
#
#        count_room_living  count_room_maid  count_room_storage  \
# count       10026.000000      2068.000000         4108.000000
# mean            1.053860         1.048356            1.054771
# std             0.262145         0.227696            0.269673
# min             1.000000         1.000000            1.000000
# 25%             1.000000         1.000000            1.000000
# 50%             1.000000         1.000000            1.000000
# 75%             1.000000         1.000000            1.000000
# max             5.000000         4.000000            5.000000
#
#        count_room_utility
# count          699.000000
# mean             1.058655
# std              0.284749
# min              1.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              4.000000

# %%
data1['propertytype_name_en']
# Out:
# 0                 Condo
# 1            Twin house
# 2                 Condo
# 3                 Condo
# 4              Townhome
#               ...
# 42620    Detached House
# 42621    Detached House
# 42622          Townhome
# 42623    Detached House
# 42624    Detached House
# Name: propertytype_name_en, Length: 42625, dtype: object

# %%
data1['propertytype_name_en'][42624]
# Out:
# 'Detached House'

# %%
data1.iloc[42619,5]
# Out:
# 'Detached House'

# %%
data1.iloc[-6,5]
# Out:
# 'Detached House'

# %% [markdown]
# # Table Slicing

# %%
data1.iloc[-20:,7:10]
# Out:
#        area_total_min_wa  area_usable_min   price_min
# 42605                NaN              NaN   1300000.0
# 42606                NaN            349.0  18000000.0
# 42607                NaN             71.0  17000000.0
# 42608                NaN              NaN         NaN
# 42609                NaN              NaN         NaN
# 42610                NaN            250.0   5990000.0
# 42611                NaN              NaN         NaN
# 42612                NaN            154.0   4800000.0
# 42613               50.0            105.0   1900000.0
# 42614                NaN            142.1   4880000.0
# 42615                NaN             60.0   3500000.0
# 42616                NaN            200.0         NaN
# 42617                NaN              NaN         NaN
# 42618                NaN            130.0  36500000.0
# 42619                NaN            353.0  23590000.0
# 42620                NaN            157.0         NaN
# 42621                NaN            223.0   7490000.0
# 42622                NaN            133.0         NaN
# 42623                NaN            180.0   3200000.0
# 42624                NaN            170.0   3790000.0

# %% [markdown]
# # Table Query

# %%
data1[data1['propertytype_name_en']=='Condo'] ## ใช้ logical condition ในการเลือก data
# Out:
#        row_number     unittype_id     project_id                      name_th  \
# 0           27501   unittype_9565   project_2446                    2 Bedroom
# 2           28865    unittype_471    project_143             1 Bedroom Type B
# 3           24988  unittype_19506   project_7766             Studio Floor 1-2
# 10           5238  unittype_15162   project_4107             Studio Floor 5-8
# 14          29911  unittype_25780  project_10313                    1 Bedroom
# ...           ...             ...            ...                          ...
# 42590       23548  unittype_15279   project_3976  1 Bedroom Tower 1 Floor 5-6
# 42602       39384   unittype_3476    project_812             2 Bedroom Type A
# 42604        1058   unittype_7949   project_2641            Typical 1 Bedroom
# 42607       13546  unittype_40152  project_17505                    2 Bedroom
# 42615       36172  unittype_34140  project_14663                    2 Bedroom
#
#        propertytype_id propertytype_name_en propertytype_name_th  \
# 0                    2                Condo                คอนโด
# 2                    2                Condo                คอนโด
# 3                    2                Condo                คอนโด
# 10                   2                Condo                คอนโด
# 14                   2                Condo                คอนโด
# ...                ...                  ...                  ...
# 42590                2                Condo                คอนโด
# 42602                2                Condo                คอนโด
# 42604                2                Condo                คอนโด
# 42607                2                Condo                คอนโด
# 42615                2                Condo                คอนโด
#
#        area_total_min_wa  area_usable_min   price_min  ...  count_room_guest  \
# 0                    NaN             37.3   2500000.0  ...               1.0
# 2                    NaN             28.0         NaN  ...               NaN
# 3                    NaN             27.0    170000.0  ...               NaN
# 10                   NaN             30.0   1116000.0  ...               NaN
# 14                   NaN             50.0   1700000.0  ...               NaN
# ...                  ...              ...         ...  ...               ...
# 42590                NaN             33.0    989000.0  ...               NaN
# 42602                NaN             94.0   6345000.0  ...               NaN
# 42604                NaN             34.0   3120000.0  ...               NaN
# 42607                NaN             71.0  17000000.0  ...               NaN
# 42615                NaN             60.0   3500000.0  ...               1.0
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 0                     1.0                NaN              NaN
# 2                     NaN                NaN              NaN
# 3                     NaN                NaN              NaN
# 10                    1.0                NaN              NaN
# 14                    1.0                NaN              NaN
# ...                   ...                ...              ...
# 42590                 NaN                NaN              NaN
# 42602                 NaN                NaN              NaN
# 42604                 1.0                1.0              NaN
# 42607                 1.0                1.0              NaN
# 42615                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility      date_created  \
# 0                     NaN                 NaN  19/11/2021 18:00
# 2                     NaN                 NaN   14/1/2022 15:00
# 3                     NaN                 NaN   4/12/2020 10:40
# 10                    NaN                 NaN  12/11/2021 13:21
# 14                    NaN                 NaN  12/11/2021 13:22
# ...                   ...                 ...               ...
# 42590                 NaN                 NaN  12/11/2021 13:21
# 42602                 NaN                 NaN   14/1/2022 11:00
# 42604                 NaN                 NaN  12/11/2021 13:25
# 42607                 NaN                 NaN  12/11/2021 13:23
# 42615                 NaN                 NaN   28/2/2022 15:30
#
#            date_updated  source  \
# 0      19/11/2021 17:44  baania
# 2       14/1/2022 14:40  baania
# 3       14/10/2020 1:06  baania
# 10      14/10/2020 0:58  baania
# 14      14/10/2020 1:09  baania
# ...                 ...     ...
# 42590   14/10/2020 0:58  baania
# 42602   14/1/2022 10:32  baania
# 42604  27/10/2020 15:03  baania
# 42607  14/10/2020 20:30  baania
# 42615   28/2/2022 14:43  baania
#
#                                             url_unittype
# 0      https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 2      https://baania.com/th/project/วันพลัส-นายน์ทีน...
# 3      https://baania.com/th/project/บ้านสวนชมน้ำ-776...
# 10     https://baania.com/th/project/ซิตี้โฮม-รัตนาธิ...
# 14     https://baania.com/th/project/พัทยา-เดล-เรย์-1...
# ...                                                  ...
# 42590  https://baania.com/th/project/เดอะ-สตาร์-คอนโด...
# 42602  https://baania.com/th/project/เดอะ-ยูนีค-คอนโด...
# 42604  https://baania.com/th/project/ศุภาลัย-ไลท์-รัช...
# 42607  https://baania.com/th/project/เดอะ-ไลน์-สาทร-1...
# 42615  https://baania.com/th/project/พลัส-คอนโด-โคราช...
#
# [12717 rows x 27 columns]

# %%
data1['propertytype_name_en']=='Condo'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 42620    False
# 42621    False
# 42622    False
# 42623    False
# 42624    False
# Name: propertytype_name_en, Length: 42625, dtype: bool

# %% [markdown]
# หาพื้นที่เฉลี่ยของบ้านที่ราคาเกิน 10 ล้าน

# %%
data1[data1['price_min']>10000000]
# Out:
#        row_number               unittype_id                project_id  \
# 5           30766             unittype_8026              project_2694
# 11           2452             unittype_8521              project_2906
# 31          17879  5f682d5d0499a4001b30c305  5f6472855bdc5300198eb80a
# 35           6309             unittype_3461               project_754
# 37          26913            unittype_23137              project_9231
# ...           ...                       ...                       ...
# 42576       35213            unittype_22962              project_8609
# 42606       24384            unittype_14126              project_5602
# 42607       13546            unittype_40152             project_17505
# 42618       22299            unittype_13674              project_5356
# 42619       11944            unittype_34884             project_15005
#
#                    name_th  propertytype_id propertytype_name_en  \
# 5            Luciano Grand                1       Detached House
# 11      New Villa Valdivia                1       Detached House
# 31              2BR Duplex                2                Condo
# 35                  Type C                1       Detached House
# 37               4 Bedroom                2                Condo
# ...                    ...              ...                  ...
# 42576            Manhattan                1       Detached House
# 42606      ทาวน์โฮมสามชั้น                3             Townhome
# 42607            2 Bedroom                2                Condo
# 42618  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 42619             Ametrine                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 5                     บ้าน               70.5            198.0  11700000.0
# 11                    บ้าน                NaN            441.0  36900000.0
# 31                   คอนโด                NaN            293.0  34222500.0
# 35                    บ้าน                NaN            390.0  11000000.0
# 37                   คอนโด                NaN            305.0  24000000.0
# ...                    ...                ...              ...         ...
# 42576                 บ้าน                NaN            465.0  28900000.0
# 42606             ทาวน์โฮม                NaN            349.0  18000000.0
# 42607                คอนโด                NaN             71.0  17000000.0
# 42618                 บ้าน                NaN            130.0  36500000.0
# 42619                 บ้าน                NaN            353.0  23590000.0
#
#        ...  count_room_guest  count_room_kitchen  count_room_living  \
# 5      ...               NaN                 NaN                NaN
# 11     ...               1.0                 1.0                1.0
# 31     ...               NaN                 1.0                1.0
# 35     ...               NaN                 1.0                1.0
# 37     ...               NaN                 NaN                NaN
# ...    ...               ...                 ...                ...
# 42576  ...               NaN                 2.0                2.0
# 42606  ...               1.0                 2.0                NaN
# 42607  ...               NaN                 1.0                1.0
# 42618  ...               NaN                 NaN                1.0
# 42619  ...               1.0                 1.0                1.0
#
#        count_room_maid  count_room_storage  count_room_utility  \
# 5                  NaN                 NaN                 NaN
# 11                 1.0                 NaN                 NaN
# 31                 NaN                 NaN                 NaN
# 35                 NaN                 NaN                 NaN
# 37                 NaN                 NaN                 NaN
# ...                ...                 ...                 ...
# 42576              1.0                 NaN                 NaN
# 42606              NaN                 NaN                 NaN
# 42607              NaN                 NaN                 NaN
# 42618              NaN                 NaN                 NaN
# 42619              1.0                 1.0                 NaN
#
#            date_created      date_updated  source  \
# 5      12/11/2021 13:22  14/10/2020 19:35  baania
# 11     12/11/2021 13:22  14/10/2020 19:35  baania
# 31     12/11/2021 13:26  25/12/2020 11:27  baania
# 35      4/12/2020 10:44  14/10/2020 21:21  baania
# 37     12/11/2021 13:21   14/10/2020 1:08  baania
# ...                 ...               ...     ...
# 42576  12/11/2021 13:33   3/10/2021 15:21  baania
# 42606   4/12/2020 10:45  14/10/2020 22:59  baania
# 42607  12/11/2021 13:23  14/10/2020 20:30  baania
# 42618   4/12/2020 10:38   14/10/2020 0:47  baania
# 42619     3/6/2022 1:00     3/6/2022 0:51  baania
#
#                                             url_unittype
# 5      https://baania.com/th/project/คาซ่า-แกรนด์-ตาก...
# 11     https://baania.com/th/project/แกรนด์-บางกอก-บู...
# 31     https://baania.com/th/project/ไบรท์-ภูเก็ต-5f6...
# 35     https://baania.com/th/project/บ้านล้านนาธารา-เ...
# 37     https://baania.com/th/project/บางกอก-การ์เด้น-...
# ...                                                  ...
# 42576  https://baania.com/th/project/เดอะ-เจนทริ-สุขุ...
# 42606  https://baania.com/th/project/เดอะ-ซีนีธ-5602/...
# 42607  https://baania.com/th/project/เดอะ-ไลน์-สาทร-1...
# 42618  https://baania.com/th/project/บ้านศุธาวัลย์-53...
# 42619  https://baania.com/th/project/เศรษฐสิริ-แจ้งวั...
#
# [3481 rows x 27 columns]

# %%
data1[data1['price_min']>10000000].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   3481.000000      3481.000000         304.000000      3354.000000
# mean   21066.205401       215.859523          52.622796       286.948606
# std    12478.117102      2035.944151          31.406177       185.081647
# min        1.000000         1.000000           1.000000        30.000000
# 25%     9796.000000         1.000000          30.000000       155.000000
# 50%    21525.000000         1.000000          51.400000       265.000000
# 75%    32420.000000         2.000000          72.625000       362.750000
# max    42620.000000     20000.000000         335.000000      2548.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.481000e+03            138.000000             0.0
# mean   2.577675e+07              4.536232             NaN
# std    2.789259e+07              2.015123             NaN
# min    1.003000e+07              1.000000             NaN
# 25%    1.300000e+07              3.000000             NaN
# 50%    1.700000e+07              4.000000             NaN
# 75%    2.790200e+07              5.750000             NaN
# max    5.800000e+08             10.000000             NaN
#
#        count_floor_internal  count_parking  count_room_bath  count_room_bed  \
# count           2149.000000    1784.000000      3420.000000     3411.000000
# mean               2.346208       2.867152         3.687427        3.357666
# std                0.816617       1.284865         1.458689        1.101538
# min                0.000000       1.000000         0.000000        0.000000
# 25%                2.000000       2.000000         3.000000        3.000000
# 50%                2.000000       3.000000         4.000000        3.000000
# 75%                3.000000       3.000000         5.000000        4.000000
# max                7.000000      10.000000        10.000000       10.000000
#
#        count_room_dinning  count_room_guest  count_room_kitchen  \
# count         1570.000000       1236.000000         1897.000000
# mean             1.007006          1.046926            1.061676
# std              0.083437          0.222751            0.247118
# min              1.000000          1.000000            1.000000
# 25%              1.000000          1.000000            1.000000
# 50%              1.000000          1.000000            1.000000
# 75%              1.000000          1.000000            1.000000
# max              2.000000          3.000000            3.000000
#
#        count_room_living  count_room_maid  count_room_storage  \
# count        1396.000000       989.000000          497.000000
# mean            1.169054         1.070779            1.108652
# std             0.473001         0.275603            0.411853
# min             1.000000         1.000000            1.000000
# 25%             1.000000         1.000000            1.000000
# 50%             1.000000         1.000000            1.000000
# 75%             1.000000         1.000000            1.000000
# max             5.000000         4.000000            4.000000
#
#        count_room_utility
# count           83.000000
# mean             1.120482
# std              0.424769
# min              1.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              4.000000

# %% [markdown]
# # Quiz 4
#
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท
# 2. พื้นที่ของ และ จำนวนห้องนอนของบ้านที่แพงที่สุด
# 3. จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด
# 4. ชนิดของบ้านที่แพงที่สุด
# 5. บ้านชนิดไหนมีปริมาณมากที่สุด

# %%
data1[(data1['price_min']>30000000) & (data1['price_min']<50000000)].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count    411.000000       411.000000          40.000000       401.000000
# mean   20715.958637       147.554745          57.459250       373.272419
# std    12307.353347      1704.408131          51.359674       179.516009
# min      544.000000         1.000000          11.000000        58.000000
# 25%     9834.000000         1.000000          26.000000       225.000000
# 50%    18788.000000         1.000000          52.500000       385.000000
# 75%    32105.500000         2.000000          67.425000       490.000000
# max    42502.000000     20000.000000         335.000000      1252.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  4.110000e+02              7.000000             0.0
# mean   3.800397e+07              5.285714             NaN
# std    5.376645e+06              2.497618             NaN
# min    3.008000e+07              3.000000             NaN
# 25%    3.340000e+07              3.500000             NaN
# 50%    3.690000e+07              5.000000             NaN
# 75%    4.200000e+07              6.000000             NaN
# max    4.990000e+07             10.000000             NaN
#
#        count_floor_internal  count_parking  count_room_bath  count_room_bed  \
# count            251.000000     213.000000       404.000000      407.000000
# mean               2.486056       3.511737         4.292079        3.719902
# std                0.811668       1.203808         1.436441        1.019597
# min                1.000000       1.000000         0.000000        0.000000
# 25%                2.000000       3.000000         3.000000        3.000000
# 50%                2.000000       3.000000         4.000000        4.000000
# 75%                3.000000       4.000000         5.000000        4.000000
# max                6.000000      10.000000         8.000000        6.000000
#
#        count_room_dinning  count_room_guest  count_room_kitchen  \
# count          184.000000        160.000000          222.000000
# mean             1.005435          1.093750            1.112613
# std              0.073721          0.313168            0.330807
# min              1.000000          1.000000            1.000000
# 25%              1.000000          1.000000            1.000000
# 50%              1.000000          1.000000            1.000000
# 75%              1.000000          1.000000            1.000000
# max              2.000000          3.000000            3.000000
#
#        count_room_living  count_room_maid  count_room_storage  \
# count         169.000000       153.000000           57.000000
# mean            1.171598         1.104575            1.122807
# std             0.463062         0.327739            0.425532
# min             1.000000         1.000000            1.000000
# 25%             1.000000         1.000000            1.000000
# 50%             1.000000         1.000000            1.000000
# 75%             1.000000         1.000000            1.000000
# max             4.000000         3.000000            3.000000
#
#        count_room_utility
# count           14.000000
# mean             1.142857
# std              0.363137
# min              1.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              2.000000
