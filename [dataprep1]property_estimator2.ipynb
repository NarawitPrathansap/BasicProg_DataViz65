# %% [markdown]
# <a href="https://colab.research.google.com/github/NarawitPrathansap/BasicProg_DataViz65/blob/main/%5Bdataprep1%5Dproperty_estimator2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
home = pd.read_excel('/content/gdrive/MyDrive/bsc_DPBM_data_N/คำตอบนักประเมิน.xlsx',sheet_name=0)
home.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# ## นักประเมินคนที่ 1

# %%
est1_home = home[home['ID ผู้ประเมิน']==1]

# %%
est1_home.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %% [markdown]
# ## นักประเมินคนที่ 2

# %%
est2_home = home[home['ID ผู้ประเมิน']==2]

# %%
est2_home.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# ### นักประเมินคนที่ 1 ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
est1_home['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est1_home['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
est1_home.describe()['ประเมินราคาซื้อ-ขาย']
# Out:
# count    1.000000e+02
# mean     3.938500e+06
# std      2.368553e+06
# min      6.000000e+05
# 25%      2.775000e+06
# 50%      3.600000e+06
# 75%      4.500000e+06
# max      1.600000e+07
# Name: ประเมินราคาซื้อ-ขาย, dtype: float64

# %% [markdown]
# ### นักประเมินคนที่ 2 ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
est2_home['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est2_home['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
est2_home.describe()['ประเมินราคาซื้อ-ขาย']
# Out:
# count    8.900000e+01
# mean     4.153258e+06
# std      2.386901e+06
# min      9.900000e+05
# 25%      2.600000e+06
# 50%      3.900000e+06
# 75%      4.900000e+06
# max      1.700000e+07
# Name: ประเมินราคาซื้อ-ขาย, dtype: float64

# %% [markdown]
# #HW1 เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนของราคาตั้งขาย

# %% [markdown]
# ## บ้าน

# %% [markdown]
# ### สร้างตาราง

# %%
est2_home['ประเมินโดย2']  = est2_home['post id'].map(est2_home.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
# Out:
# <ipython-input-13-a017043473c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_home['ประเมินโดย2']  = est2_home['post id'].map(est2_home.set_index('post id')['ประเมินราคาซื้อ-ขาย'])

# %%
est2_home['ประเมินโดย1'] = est2_home['post id'].map(est1_home.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_home.head()
# Out:
# <ipython-input-14-b224819e6b7e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2_home['ประเมินโดย1'] = est2_home['post id'].map(est1_home.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7              2  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9              2  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
home_mape = est2_home[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
home_mape.isnull().any()
home_mape = home_mape.dropna(subset= ['ประเมินโดย2'])

# %%
home_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2
# 1      2700000.0
# 3      2400000.0
# 5      9000000.0
# 7      3700000.0
# 9      2500000.0
# ..           ...
# 185    5000000.0
# ...

# %% [markdown]
# ### MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error #as MAPE

# %%
a = home_mape['ราคาทรัพย์']
a_pred_1 = home_mape['ประเมินโดย1']
a_pred_2 = home_mape['ประเมินโดย2']

# %%
mean_absolute_percentage_error(a,a_pred_1 )
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(บ้าน) และ ราคาของผู้ประเมินคนที่1 เท่ากับ {mean_absolute_percentage_error(a,a_pred_1)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(บ้าน) และ ราคาของผู้ประเมินคนที่1 เท่ากับ 12.32%

# %%
mean_absolute_percentage_error(a,a_pred_2)
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(บ้าน) และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(a,a_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(บ้าน) และ ราคาของผู้ประเมินคนที่2 เท่ากับ 10.42%

# %%
mean_absolute_percentage_error(a_pred_1,a_pred_2 )
print(f'ค่า MAPE ระหว่าง  ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(a_pred_1,a_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง  ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ 13.63%

# %% [markdown]
# ## ที่ดิน

# %%
land = pd.read_excel('/content/gdrive/MyDrive/bsc_DPBM_data_N/คำตอบนักประเมิน.xlsx',sheet_name=1)
land.head()
# Out:
#    ID ผู้ประเมิน                               post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1              2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2              4  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3              1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4              2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     2800000            1800000.0
# 1                        มั่นใจ     2800000            2000000.0
# 2                        มั่นใจ     2800000            3000000.0
# 3                        มั่นใจ    14900000            8000000.0
# 4                        มั่นใจ    14900000           12000000.0
#
#             ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                             8,000-25,000                        NaN
# ...

# %% [markdown]
# ### สร้างตาราง

# %%
est1_land = land [land ['ID ผู้ประเมิน']==1]

# %%
est2_land = land [land ['ID ผู้ประเมิน']==2]

# %%
est1_land['ประเมินโดย1']  = est1_land['post id'].map(est1_land.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
# Out:
# <ipython-input-25-9abd320c0b45>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_land['ประเมินโดย1']  = est1_land['post id'].map(est1_land.set_index('post id')['ประเมินราคาซื้อ-ขาย'])

# %%
est1_land['ประเมินโดย2']  = est1_land['post id'].map(est2_land.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
# Out:
# <ipython-input-26-88d3795377e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_land['ประเมินโดย2']  = est1_land['post id'].map(est2_land.set_index('post id')['ประเมินราคาซื้อ-ขาย'])

# %%
est1_land.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 0               1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3               1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6               1  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9               1  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12              1  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                         มั่นใจ     2800000            1800000.0
# 3                         มั่นใจ    14900000            8000000.0
# 6                         มั่นใจ    90000000           18000000.0
# 9                         มั่นใจ    65000000           35000000.0
# 12                        มั่นใจ     3000000            2200000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                    8,000-25,000                        NaN
# ...

# %%
land_mape = est1_land[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
land_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 0     https://nayoo.co/khonkaen/posts/1033     2800000    1800000.0
# 3     https://nayoo.co/khonkaen/posts/1711    14900000    8000000.0
# 6     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# 9     https://nayoo.co/khonkaen/posts/1732    65000000   35000000.0
# 12    https://nayoo.co/khonkaen/posts/1866     3000000    2200000.0
# ..                                     ...         ...          ...
# 201  https://nayoo.co/khonkaen/posts/14539     5000000    4000000.0
# 203  https://nayoo.co/khonkaen/posts/16072      750000     500000.0
# 205  https://nayoo.co/khonkaen/posts/17093     2650000    2000000.0
# 207  https://nayoo.co/khonkaen/posts/17112     1300000    1500000.0
# 209  https://nayoo.co/khonkaen/posts/17145     3000000    2500000.0
#
#      ประเมินโดย2
# 0      2000000.0
# 3     12000000.0
# 6     70000000.0
# 9     60000000.0
# 12     2500000.0
# ..           ...
# 201    4000000.0
# ...

# %% [markdown]
# ### MAPE

# %%
b = land_mape['ราคาทรัพย์']
b_pred_1 = land_mape['ประเมินโดย1']
b_pred_2 = land_mape['ประเมินโดย2']

# %%
mean_absolute_percentage_error(b,b_pred_1)
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์ และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(b,b_pred_1)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์ และ ราคาของผู้ประเมินคนที่2 เท่ากับ 41.34%

# %%
mean_absolute_percentage_error(b,b_pred_2 )
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(ที่ดิน) และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(b,b_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(ที่ดิน) และ ราคาของผู้ประเมินคนที่2 เท่ากับ 40.12%

# %%
mean_absolute_percentage_error(b_pred_1,b_pred_2 )
print(f'ค่า MAPE ระหว่าง ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(b_pred_1,b_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ 74.08%

# %% [markdown]
# ## คอนโด

# %%
condo = pd.read_excel('/content/gdrive/MyDrive/bsc_DPBM_data_N/คำตอบนักประเมิน.xlsx',sheet_name=2)
condo.head()
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1   1930000.0            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2   2438000.0            2800000.0    35,000-80,000 บาท/ตารางเมตร
# 3   1600000.0            2300000.0    30,000-80,000 บาท/ตารางเมตร
# 4   1860000.0            1800000.0    30,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                    ให้คะแนนทรัพย์  Unnamed: 9  \
# ...

# %%
condo['ประเมินโดย1'] = condo['ประเมินราคาซื้อ-ขาย']

# %%
condo_mape = condo[['post id','ราคาทรัพย์','ประเมินโดย1']]
condo_mape
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย1
# 0     32.0   3500000.0    3500000.0
# 1     36.0   1930000.0    2200000.0
# 2    603.0   2438000.0    2800000.0
# 3   1395.0   1600000.0    2300000.0
# 4   1443.0   1860000.0    1800000.0
# 5   1609.0   1490000.0    1500000.0
# 6   1640.0   1280000.0    1600000.0
# 7   1641.0   4290000.0    2700000.0
# 8   1650.0   1700000.0    1550000.0
# 9   1840.0   3790000.0    2800000.0

# %% [markdown]
# ### MAPE

# %%
c = condo_mape['ราคาทรัพย์']
c_pred_1 = condo_mape['ประเมินโดย1']

# %%
mean_absolute_percentage_error(c,c_pred_1)
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(คอนโด) และ ราคาของผู้ประเมินคนที่1 เท่ากับ {mean_absolute_percentage_error(c,c_pred_1)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(คอนโด) และ ราคาของผู้ประเมินคนที่1 เท่ากับ 17.35%

# %% [markdown]
# ## ทาว์นโฮม

# %%
townhome = pd.read_excel('/content/gdrive/MyDrive/bsc_DPBM_data_N/คำตอบนักประเมิน.xlsx',sheet_name=3)
townhome.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2              1  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4              1  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   1045000.0             700000.0
# 1                        มั่นใจ   1045000.0            1500000.0
# 2                        มั่นใจ    935000.0             700000.0
# 3                        มั่นใจ    935000.0            1500000.0
# 4                        มั่นใจ   3520000.0            3500000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                         NaN
# ...

# %% [markdown]
# ### สร้างตาราง

# %%
est1_townhome = townhome [townhome ['ID ผู้ประเมิน']==1]

# %%
est2_townhome = townhome [townhome ['ID ผู้ประเมิน']==2]

# %%
print(len(est1_townhome))
print(len(est2_townhome))
# Out:
# 120
# 120

# %%
est1_townhome['ประเมินโดย1']  = est1_townhome['post id'].map(est1_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
# Out:
# <ipython-input-42-87c88ec3b543>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_townhome['ประเมินโดย1']  = est1_townhome['post id'].map(est1_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย'])

# %%
est1_townhome['ประเมินโดย2']  = est1_townhome['post id'].map(est2_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est1_townhome.head()
# Out:
# <ipython-input-43-cd110fbc2de3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_townhome['ประเมินโดย2']  = est1_townhome['post id'].map(est2_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2              1  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4              1  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 6              1  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 8              1  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
townhome_mape = est1_townhome[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
townhome_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 0      https://nayoo.co/khonkaen/posts/548   1045000.0     700000.0
# 2      https://nayoo.co/khonkaen/posts/549    935000.0     700000.0
# 4      https://nayoo.co/khonkaen/posts/579   3520000.0    3500000.0
# 6      https://nayoo.co/khonkaen/posts/580   3850000.0    3500000.0
# 8      https://nayoo.co/khonkaen/posts/582    990000.0    1000000.0
# ..                                     ...         ...          ...
# 125  https://nayoo.co/khonkaen/posts/18547   1430000.0    1000000.0
# 126  https://nayoo.co/khonkaen/posts/18551   1980000.0    1500000.0
# 127  https://nayoo.co/khonkaen/posts/19434   2000000.0    1600000.0
# 128  https://nayoo.co/khonkaen/posts/19501   1790000.0    1600000.0
# 129  https://nayoo.co/khonkaen/posts/20367   1590000.0    1700000.0
#
#      ประเมินโดย2
# 0      1500000.0
# 2      1500000.0
# 4      4000000.0
# 6      3200000.0
# 8       800000.0
# ..           ...
# 125    1200000.0
# ...

# %% [markdown]
# ### MAPE

# %%
d = townhome_mape['ราคาทรัพย์']
d_pred_1 = townhome_mape['ประเมินโดย1']
d_pred_2 = townhome_mape['ประเมินโดย2']

# %%
mean_absolute_percentage_error(d,d_pred_1)
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(ทาวน์โฮม) และ ราคาของผู้ประเมินคนที่1 เท่ากับ {mean_absolute_percentage_error(d,d_pred_1)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(ทาวน์โฮม) และ ราคาของผู้ประเมินคนที่1 เท่ากับ 11.37%

# %%
mean_absolute_percentage_error(d,d_pred_2)
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(ทาวน์โฮม)  และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(d,d_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(ทาวน์โฮม)  และ ราคาของผู้ประเมินคนที่2 เท่ากับ 8.77%

# %%
mean_absolute_percentage_error(d_pred_1,d_pred_2)
print(f'ค่า MAPE ระหว่าง  ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(d_pred_1,d_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง  ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ 11.21%

# %% [markdown]
# ## อาคารพาณิชย์

# %%
commercial = pd.read_excel('/content/gdrive/MyDrive/bsc_DPBM_data_N/คำตอบนักประเมิน.xlsx',sheet_name=4)
commercial.head()
# Out:
#    ID ผู้ประเมิน                             post id          property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2              1  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4              1  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   7000000.0            6000000.0
# 1                        มั่นใจ   7000000.0            8000000.0
# 2                        มั่นใจ  12000000.0           12000000.0
# 3                        มั่นใจ  12000000.0           12000000.0
# 4                        มั่นใจ  22500000.0           13500000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# ...

# %% [markdown]
# ### สร้างตาราง

# %%
est1_commercial = commercial [commercial ['ID ผู้ประเมิน']==1]

# %%
est2_commercial = commercial [commercial ['ID ผู้ประเมิน']==2]

# %%
print(len(est1_commercial))
print(len(est2_commercial))
# Out:
# 10
# 10

# %%
est1_commercial['ประเมินโดย1']  = est1_commercial['post id'].map(est1_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
# Out:
# <ipython-input-53-ebf7e069d23b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_commercial['ประเมินโดย1']  = est1_commercial['post id'].map(est1_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย'])

# %%
est1_commercial['ประเมินโดย2']  = est1_commercial['post id'].map(est2_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est1_commercial.head(3)
# Out:
# <ipython-input-54-374a98500130>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_commercial['ประเมินโดย2']  = est1_commercial['post id'].map(est2_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                             post id          property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2              1  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4              1  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   7000000.0            6000000.0
# 2                        มั่นใจ  12000000.0           12000000.0
# ...

# %%
commercial_mape = est1_commercial[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
commercial_mape
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2
# 0     https://nayoo.co/khonkaen/posts/6   7000000.0    6000000.0    8000000.0
# 2    https://nayoo.co/khonkaen/posts/17  12000000.0   12000000.0   12000000.0
# 4    https://nayoo.co/khonkaen/posts/21  22500000.0   13500000.0   20000000.0
# 6    https://nayoo.co/khonkaen/posts/22   3500000.0    4000000.0    4000000.0
# 8    https://nayoo.co/khonkaen/posts/24   3900000.0    2200000.0    3000000.0
# 10   https://nayoo.co/khonkaen/posts/30   4800000.0    3600000.0    4000000.0
# 12   https://nayoo.co/khonkaen/posts/35   2400000.0    2500000.0    2100000.0
# 14  https://nayoo.co/khonkaen/posts/497   5000000.0    3800000.0    5000000.0
# 16  https://nayoo.co/khonkaen/posts/498   7000000.0    7000000.0    8000000.0
# 18  https://nayoo.co/khonkaen/posts/499   9000000.0    8000000.0   10000000.0

# %% [markdown]
# ### MAPE

# %%
e = commercial_mape['ราคาทรัพย์']
e_pred_1 = commercial_mape['ประเมินโดย1']
e_pred_2 = commercial_mape['ประเมินโดย2']

# %%
mean_absolute_percentage_error(e,e_pred_1 )
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(อาคารพาณิชย์) และ ราคาของผู้ประเมินคนที่1 เท่ากับ {mean_absolute_percentage_error(e,e_pred_1)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(อาคารพาณิชย์) และ ราคาของผู้ประเมินคนที่1 เท่ากับ 17.64%

# %%
mean_absolute_percentage_error(e,e_pred_2)
print(f'ค่า MAPE ระหว่าง ราคาทรัพย์(อาคารพาณิชย์) และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(e,e_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาทรัพย์(อาคารพาณิชย์) และ ราคาของผู้ประเมินคนที่2 เท่ากับ 11.73%

# %%
mean_absolute_percentage_error(e_pred_1,e_pred_2)
print(f'ค่า MAPE ระหว่าง ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ {mean_absolute_percentage_error(e_pred_1,e_pred_2)*100:.2f}%')
# Out:
# ค่า MAPE ระหว่าง ราคาของผู้ประเมินคนที่1 และ ราคาของผู้ประเมินคนที่2 เท่ากับ 21.58%

# %% [markdown]
# ## เขียน function ตรวจสอบค่าที่เติม 0 ผิด

# %%
max(10,2)
# Out:
# 10

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %%
check_v(250,2500)
# Out:
# 10.0

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %%
check_v(100,1200)
# Out:
# 12.0

# %% [markdown]
# ## สร้าง column ใหม่ ลงในตาราง home โดย ค่าใน column คือค่าจาก function check(ราคาตั้งขาย,ราคาประเมิน1)

# %% [markdown]
# ### บ้าน

# %%
#บ้าน
home_mape['check1']=home_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
home_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2    check1
# 1      2700000.0  1.080000
# 3      2400000.0  1.181818
# 5      9000000.0  1.180000
# 7      3700000.0  1.257143
# ...

# %%
check1 = list()
for row in home_mape.iterrows():
     check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินโดย1']))
check1
# Out:
# [1.08,
#  1.1818181818181819,
#  1.18,
#  1.2571428571428571,
#  1.1,
#  1.271111111111111,
#  1.36,
#  1.0153846153846153,
#  1.3684,
#  1.031941031941032,
#  1.0476190476190477,
#  1.1785714285714286,
#  1.0592592592592593,
#  1.188,
#  1.1275,
#  1.1,
#  1.1157142857142857,
#  1.0371428571428571,
#  1.0588235294117647,
#  1.2571428571428571,
#  1.13125,
#  1.0,
#  1.0888888888888888,
#  1.0892333472978635,
#  1.0444444444444445,
#  1.0,
#  1.0434782608695652,
#  1.02,
#  1.25,
#  1.13,
#  1.0714285714285714,
#  1.0,
#  1.0,
#  1.3833333333333333,
#  1.03125,
#  1.1611111111111112,
#  1.0526315789473684,
#  1.5384615384615385,
#  1.0227272727272727,
#  1.1363636363636365,
#  1.1111111111111112,
#  1.1290322580645162,
#  1.1388888888888888,
#  1.0,
#  1.0933333333333333,
#  1.3093125,
#  1.21,
#  1.24,
#  1.1642857142857144,
#  1.1,
#  1.4685314685314685,
#  1.1111111111111112,
#  1.1942857142857144,
#  1.0714285714285714,
#  1.0710526315789475,
#  1.4575,
#  1.046,
#  1.09375,
# ...

# %%
home_mape['check1_2'] = check1
home_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2    check1  check1_2
# 1      2700000.0  1.080000  1.080000
# 3      2400000.0  1.181818  1.181818
# ...

# %%
check2 = list()
for row in home_mape.iterrows():
     check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินโดย2']))
check2
# Out:
# [1.0,
#  1.0833333333333333,
#  1.5254237288135593,
#  1.1891891891891893,
#  1.1,
#  1.0314685314685315,
#  1.050420168067227,
#  1.0416666666666667,
#  1.1403333333333334,
#  1.0175,
#  1.0476190476190477,
#  1.03125,
#  1.0214285714285714,
#  1.0607142857142857,
#  1.025,
#  1.0607142857142857,
#  1.0847222222222221,
#  1.0371428571428571,
#  1.0,
#  1.125,
#  1.1049723756906078,
#  1.1904761904761905,
#  1.0888888888888888,
#  1.0054461667364893,
#  1.0425531914893618,
#  1.125,
#  1.0434782608695652,
#  1.0364145658263306,
#  1.0,
#  1.0324483775811208,
#  1.04,
#  1.2,
#  1.04,
#  1.1318181818181818,
#  1.0,
#  1.045,
#  1.0526315789473684,
#  3.3333333333333335,
#  1.0227272727272727,
#  1.04,
#  1.08,
#  1.2903225806451613,
#  1.1219512195121952,
#  1.125,
#  1.2195121951219512,
#  1.2322941176470588,
#  1.0755555555555556,
#  1.1366666666666667,
#  1.0736196319018405,
#  1.1,
#  1.048951048951049,
#  1.1111111111111112,
#  1.045,
#  1.0666666666666667,
# ...

# %%
home_mape['check1_2'] = check1
home_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2    check1  check1_2
# 1      2700000.0  1.080000  1.080000
# 3      2400000.0  1.181818  1.181818
# ...

# %%
home_mape['check2']=home_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
home_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2    check1  check1_2    check2
# 1      2700000.0  1.080000  1.080000  1.000000
# 3      2400000.0  1.181818  1.181818  1.083333
# ...

# %%
home_mape.sort_values(by=['check1_2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 75       https://nayoo.co/khonkaen/posts/1    390000.0     600000.0
# 177  https://nayoo.co/khonkaen/posts/19450   2100000.0    3200000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 101   https://nayoo.co/khonkaen/posts/6010   2860000.0    4200000.0
# ..                                     ...         ...          ...
# 167   https://nayoo.co/khonkaen/posts/9141   3500000.0    3500000.0
# 51    https://nayoo.co/khonkaen/posts/1149   4000000.0    4000000.0
# 63    https://nayoo.co/khonkaen/posts/2033   1200000.0    1200000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 87    https://nayoo.co/khonkaen/posts/3905   1200000.0    1200000.0
#
#      ประเมินโดย2    check1  check1_2    check2
# 187    2500000.0  1.800000  1.800000  1.250000
# 75     1300000.0  1.538462  1.538462  3.333333
# ...

# %%
home_mape.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 75       https://nayoo.co/khonkaen/posts/1    390000.0     600000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 111   https://nayoo.co/khonkaen/posts/6045   2915000.0    2000000.0
# 83    https://nayoo.co/khonkaen/posts/3721   3100000.0    3500000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# ..                                     ...         ...          ...
# 169  https://nayoo.co/khonkaen/posts/11264   6500000.0    5600000.0
# 69    https://nayoo.co/khonkaen/posts/2262   3200000.0    3300000.0
# 57    https://nayoo.co/khonkaen/posts/1895   1200000.0    1500000.0
# 37     https://nayoo.co/khonkaen/posts/760   1800000.0    1700000.0
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
#
#      ประเมินโดย2    check1  check1_2    check2
# 75     1300000.0  1.538462  1.538462  3.333333
# 5      9000000.0  1.180000  1.180000  1.525424
# ...

# %% [markdown]
# ### ที่ดิน

# %%
#ที่ดิน
land_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 0     https://nayoo.co/khonkaen/posts/1033     2800000    1800000.0
# 3     https://nayoo.co/khonkaen/posts/1711    14900000    8000000.0
# 6     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# 9     https://nayoo.co/khonkaen/posts/1732    65000000   35000000.0
# 12    https://nayoo.co/khonkaen/posts/1866     3000000    2200000.0
# ..                                     ...         ...          ...
# 201  https://nayoo.co/khonkaen/posts/14539     5000000    4000000.0
# 203  https://nayoo.co/khonkaen/posts/16072      750000     500000.0
# 205  https://nayoo.co/khonkaen/posts/17093     2650000    2000000.0
# 207  https://nayoo.co/khonkaen/posts/17112     1300000    1500000.0
# 209  https://nayoo.co/khonkaen/posts/17145     3000000    2500000.0
#
#      ประเมินโดย2
# 0      2000000.0
# 3     12000000.0
# 6     70000000.0
# 9     60000000.0
# 12     2500000.0
# ..           ...
# 201    4000000.0
# ...

# %%
land_mape['check1']=land_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
land_mape['check2']=land_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
land_mape
# Out:
# <ipython-input-74-61f9da694d35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land_mape['check1']=land_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
# <ipython-input-74-61f9da694d35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land_mape['check2']=land_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# ...

# %%
land_mape.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 195  https://nayoo.co/khonkaen/posts/13702    90000000    4500000.0
# 113   https://nayoo.co/khonkaen/posts/7955     2600000   32000000.0
# 59    https://nayoo.co/khonkaen/posts/9203   160000000   14000000.0
# 46    https://nayoo.co/khonkaen/posts/7349   245000000   24000000.0
# 6     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# ..                                     ...         ...          ...
# 183   https://nayoo.co/khonkaen/posts/9598     3900000    4000000.0
# 79    https://nayoo.co/khonkaen/posts/3447      980000    1000000.0
# 101   https://nayoo.co/khonkaen/posts/1663     1485000    1500000.0
# 123  https://nayoo.co/khonkaen/posts/12762      650000     650000.0
# 131   https://nayoo.co/khonkaen/posts/1599     2500000    2500000.0
#
#      ประเมินโดย2     check1     check2
# 195   75000000.0  20.000000   1.200000
# 113    2000000.0  12.307692   1.300000
# ...

# %%
land_mape.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 59    https://nayoo.co/khonkaen/posts/9203   160000000   14000000.0
# 46    https://nayoo.co/khonkaen/posts/7349   245000000   24000000.0
# 149   https://nayoo.co/khonkaen/posts/3561     7374550    6000000.0
# 189  https://nayoo.co/khonkaen/posts/12250     2300000    2500000.0
# 145   https://nayoo.co/khonkaen/posts/3341     1700000    1600000.0
# ..                                     ...         ...          ...
# 105   https://nayoo.co/khonkaen/posts/1921     8080000    2800000.0
# 61   https://nayoo.co/khonkaen/posts/12607     7990000   10000000.0
# 159   https://nayoo.co/khonkaen/posts/6732     3500000    2800000.0
# 203  https://nayoo.co/khonkaen/posts/16072      750000     500000.0
# 36    https://nayoo.co/khonkaen/posts/3305    14000000   12000000.0
#
#      ประเมินโดย2     check1     check2
# 59    11000000.0  11.428571  14.545455
# 46    18000000.0  10.208333  13.611111
# ...

# %% [markdown]
# ### ทาวน์โฮม

# %%
#ทาวน์โฮม
townhome_mape
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 0      https://nayoo.co/khonkaen/posts/548   1045000.0     700000.0
# 2      https://nayoo.co/khonkaen/posts/549    935000.0     700000.0
# 4      https://nayoo.co/khonkaen/posts/579   3520000.0    3500000.0
# 6      https://nayoo.co/khonkaen/posts/580   3850000.0    3500000.0
# 8      https://nayoo.co/khonkaen/posts/582    990000.0    1000000.0
# ..                                     ...         ...          ...
# 125  https://nayoo.co/khonkaen/posts/18547   1430000.0    1000000.0
# 126  https://nayoo.co/khonkaen/posts/18551   1980000.0    1500000.0
# 127  https://nayoo.co/khonkaen/posts/19434   2000000.0    1600000.0
# 128  https://nayoo.co/khonkaen/posts/19501   1790000.0    1600000.0
# 129  https://nayoo.co/khonkaen/posts/20367   1590000.0    1700000.0
#
#      ประเมินโดย2
# 0      1500000.0
# 2      1500000.0
# 4      4000000.0
# 6      3200000.0
# 8       800000.0
# ..           ...
# 125    1200000.0
# ...

# %%
townhome_mape['check1']=townhome_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
townhome_mape['check2']=townhome_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
townhome_mape
# Out:
# <ipython-input-78-67beff5c830d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townhome_mape['check1']=townhome_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
# <ipython-input-78-67beff5c830d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townhome_mape['check2']=townhome_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# ...

# %%
townhome_mape.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 66    https://nayoo.co/khonkaen/posts/3528   2190000.0     350000.0
# 70    https://nayoo.co/khonkaen/posts/6095   2420000.0    1500000.0
# 22     https://nayoo.co/khonkaen/posts/619   1430000.0     950000.0
# 0      https://nayoo.co/khonkaen/posts/548   1045000.0     700000.0
# 64    https://nayoo.co/khonkaen/posts/3478   2190000.0    1500000.0
# ..                                     ...         ...          ...
# 118  https://nayoo.co/khonkaen/posts/17923   1990000.0    2000000.0
# 57    https://nayoo.co/khonkaen/posts/2829   2490000.0    2500000.0
# 110  https://nayoo.co/khonkaen/posts/17545   2800000.0    2800000.0
# 90   https://nayoo.co/khonkaen/posts/13411   3200000.0    3200000.0
# 93   https://nayoo.co/khonkaen/posts/17503   1500000.0    1500000.0
#
#      ประเมินโดย2    check1    check2
# 66      400000.0  6.257143  5.475000
# 70     1500000.0  1.613333  1.613333
# ...

# %%
townhome_mape.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 66    https://nayoo.co/khonkaen/posts/3528   2190000.0     350000.0
# 124  https://nayoo.co/khonkaen/posts/18090   3000000.0    2800000.0
# 70    https://nayoo.co/khonkaen/posts/6095   2420000.0    1500000.0
# 2      https://nayoo.co/khonkaen/posts/549    935000.0     700000.0
# 115  https://nayoo.co/khonkaen/posts/17742   2500000.0    2200000.0
# ..                                     ...         ...          ...
# 78    https://nayoo.co/khonkaen/posts/8101   3200000.0    3300000.0
# 110  https://nayoo.co/khonkaen/posts/17545   2800000.0    2800000.0
# 89   https://nayoo.co/khonkaen/posts/12957   1500000.0    1600000.0
# 41    https://nayoo.co/khonkaen/posts/1978   2500000.0    2700000.0
# 71    https://nayoo.co/khonkaen/posts/6104   2200000.0    2500000.0
#
#      ประเมินโดย2    check1    check2
# 66      400000.0  6.257143  5.475000
# 124    1500000.0  1.071429  2.000000
# ...

# %% [markdown]
# ### อาคารพาณิชย์

# %%
#อาคารพาณิชย์
commercial_mape
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2
# 0     https://nayoo.co/khonkaen/posts/6   7000000.0    6000000.0    8000000.0
# 2    https://nayoo.co/khonkaen/posts/17  12000000.0   12000000.0   12000000.0
# 4    https://nayoo.co/khonkaen/posts/21  22500000.0   13500000.0   20000000.0
# 6    https://nayoo.co/khonkaen/posts/22   3500000.0    4000000.0    4000000.0
# 8    https://nayoo.co/khonkaen/posts/24   3900000.0    2200000.0    3000000.0
# 10   https://nayoo.co/khonkaen/posts/30   4800000.0    3600000.0    4000000.0
# 12   https://nayoo.co/khonkaen/posts/35   2400000.0    2500000.0    2100000.0
# 14  https://nayoo.co/khonkaen/posts/497   5000000.0    3800000.0    5000000.0
# 16  https://nayoo.co/khonkaen/posts/498   7000000.0    7000000.0    8000000.0
# 18  https://nayoo.co/khonkaen/posts/499   9000000.0    8000000.0   10000000.0

# %%
commercial_mape['check1']=commercial_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
commercial_mape['check2']=commercial_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
commercial_mape
# Out:
# <ipython-input-82-f827b84391a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commercial_mape['check1']=commercial_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
# <ipython-input-82-f827b84391a8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commercial_mape['check2']=commercial_mape.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2  \
# ...

# %% [markdown]
# # HW2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน
# #Load ตารางจาก google sheet

# %% [markdown]
# https://towardsdatascience.com/different-ways-to-connect-google-drive-to-a-google-colab-notebook-part-2-b867786aed55

# %%
#import necessary library to mount personal Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('Copy of คำตอบนักประเมิน update').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
data = pd.DataFrame.from_records(rows)
#creating columns name
data.columns = data.iloc[0]
data = data.iloc[1:]
#data
# Out:
# [['ID ผู้ประเมิน', 'post id', 'property_type', 'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย', 'ปัจจัยในการประเมินราคาซื้อ-ขาย', 'เหตุผลไม่มั่นใจราคาประเมิน', 'ให้คะแนนทรัพย์'], ['01', 'https://nayoo.co/khonkaen/posts/25', 'บ้านเดี่ยว', 'มั่นใจ', '2890000', '2500000', '5,000-15,000', '', '3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน'], ['02', 'https://nayoo.co/khonkaen/posts/25', 'บ้านเดี่ยว', 'มั่นใจ', '2890000', '2700000', 'โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/หลัง', '', '4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน'], ['01', 'https://nayoo.co/khonkaen/posts/33', 'บ้านเดี่ยว', 'มั่นใจ', '2600000', '2200000', '5,000-15,000', '', '2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี'], ['02', 'https://nayoo.co/khonkaen/posts/33', 'บ้านเดี่ยว', 'มั่นใจ', '2600000', '2400000', 'ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง', '', '3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน'], ['01', 'https://nayoo.co/khonkaen/posts/495', 'บ้านเดี่ยว', 'มั่นใจ', '6050000', '5000000', '5,000-15,000', '', '3 ขายได้ ใช้ระย
# ...

# %%
import pandas as pd
sheet_id = '1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao'
sheet_name = 'home'
url = f'https://docs.google.com/spreadsheets/d/1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao/gviz/tq?tqx=out:csv&sheet=home'

# %%
pd.read_csv(url)
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
sheet_id = '1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao'
sheet_name = 'home'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
temp = pd.read_csv(url)
temp
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# ## ค่าMAPEก่อนแก้ไขข้อมูล

# %% [markdown]
# ### บ้าน

# %%
#อ่านข้อมูลจาก google sheet 
link = 'https://docs.google.com/spreadsheets/d/1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao/export?format=xlsx'
home = pd.read_excel(link,sheet_name='home')
home
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #### mape

# %%
est1_home = home[home['ID ผู้ประเมิน']==1]
est1_home = est1_home.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_home = home [home ['ID ผู้ประเมิน']==2]
est2_home = est2_home.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_home_mape = mean_absolute_percentage_error(est1_home['ราคาทรัพย์'],pd.to_numeric(est1_home['ประเมินราคาซื้อ-ขาย']))
est2_home_mape = mean_absolute_percentage_error(est2_home['ราคาทรัพย์'],pd.to_numeric(est2_home['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {est1_home_mape*100:.2f}%\nนักประเมิน คนที่ 2 = {est2_home_mape*100:.2f}%')
est2_home['ประเมิน1'] = est2_home['post id'].map(est1_home.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_home_new = est2_home.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
est2_home_new = est2_home_new[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]
one2two = mean_absolute_percentage_error(est2_home_new['ประเมินราคาซื้อ-ขาย'],est2_home_new['ประเมิน1'])
two2one = mean_absolute_percentage_error(est2_home_new['ประเมิน1'],est2_home_new['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est2_home_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 12.78%
# นักประเมิน คนที่ 2 = 13.87%
# ความผิดพลาดระหว่างนักประเมินทั้ง 14.56%
# จำนวนทรัพย์ทั้งหมด 498 ทรัพย์

# %% [markdown]
# ### ที่ดิน

# %%
#อ่านข้อมูลจาก google sheet 
link = 'https://docs.google.com/spreadsheets/d/1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao/export?format=xlsx'
land = pd.read_excel(link,sheet_name='land')
land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #### mape

# %%
est1_land = land[land['ID ผู้ประเมิน']==1]
est1_land = est1_land.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_land = land[land['ID ผู้ประเมิน']==2]
est2_land = est2_land.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_land_mape = mean_absolute_percentage_error(est1_land['ราคาทรัพย์'],pd.to_numeric(est1_land['ประเมินราคาซื้อ-ขาย']))
est2_land_mape = mean_absolute_percentage_error(est2_land['ราคาทรัพย์'],pd.to_numeric(est2_land['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {est1_land_mape*100:.2f}%\nนักประเมิน คนที่ 2 = {est2_land_mape*100:.2f}%')
est2_land['ประเมิน1'] = est2_land['post id'].map(est1_land.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_land_new = est2_land.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
est2_land_new = est2_land_new[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]
one2two = mean_absolute_percentage_error(est2_land_new['ประเมินราคาซื้อ-ขาย'],est2_land_new['ประเมิน1'])
two2one = mean_absolute_percentage_error(est2_land_new['ประเมิน1'],est2_land_new['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est2_land_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 40.83%
# นักประเมิน คนที่ 2 = 39.56%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %% [markdown]
# ### คอนโด

# %%
#อ่านข้อมูลจาก google sheet 
link = 'https://docs.google.com/spreadsheets/d/1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao/export?format=xlsx'
condo = pd.read_excel(link,sheet_name='condo')
condo
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0     3500000            3500000.0   60,000-130,000 บาท/ตารางเมตร
# ...

# %% [markdown]
# #### mape

# %%
est1_condo = condo[condo['ID ผู้ประเมิน']==1]
est1_condo = est1_condo.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_condo_new = est1_condo[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย']]
est1_condo_mape = mean_absolute_percentage_error(est1_condo_new['ราคาทรัพย์'],pd.to_numeric(est1_condo_new['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nคอนโด\nนักประเมิน คนที่ 1 = {est1_condo_mape*100:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est1_condo_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# คอนโด
# นักประเมิน คนที่ 1 = 17.35%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# ### ทาวน์โฮม

# %%
#อ่านข้อมูลจาก google sheet 
link = 'https://docs.google.com/spreadsheets/d/1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao/export?format=xlsx'
townhome = pd.read_excel(link,sheet_name='townhome')
townhome
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #### mape

# %%
est1_townhome = townhome[townhome['ID ผู้ประเมิน']==1]
est1_townhome = est1_townhome.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_townhome = townhome[townhome['ID ผู้ประเมิน']==2]
est2_townhome = est2_townhome.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_townhome_mape = mean_absolute_percentage_error(est1_townhome['ราคาทรัพย์'],pd.to_numeric(est1_townhome['ประเมินราคาซื้อ-ขาย']))
est2_townhome_mape = mean_absolute_percentage_error(est2_townhome['ราคาทรัพย์'],pd.to_numeric(est2_townhome['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {est1_townhome_mape*100:.2f}%\nนักประเมิน คนที่ 2 = {est2_townhome_mape*100:.2f}%')
est2_townhome['ประเมิน1'] = est2_townhome['post id'].map(est1_townhome.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_townhome_new = est2_townhome.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
est2_townhome_new = est2_townhome_new[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]
one2two = mean_absolute_percentage_error(est2_townhome_new['ประเมินราคาซื้อ-ขาย'],est2_townhome_new['ประเมิน1'])
two2one = mean_absolute_percentage_error(est2_townhome_new['ประเมิน1'],est2_townhome_new['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est2_townhome_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 11.57%
# นักประเมิน คนที่ 2 = 9.26%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %% [markdown]
# ### อาคารพาณิชย์

# %%
#อ่านข้อมูลจาก google sheet 
link = 'https://docs.google.com/spreadsheets/d/1a6NId_-N7tFnAxva721mT0ktVUwaTKoB0BkYvy2S7Ao/export?format=xlsx'
commercial = pd.read_excel(link,sheet_name='commercial')
commercial
# Out:
#      ID ผู้ประเมิน                               post id  \
# 0                1     https://nayoo.co/khonkaen/posts/6
# 1                2     https://nayoo.co/khonkaen/posts/6
# 2                1    https://nayoo.co/khonkaen/posts/17
# 3                2    https://nayoo.co/khonkaen/posts/17
# 4                1    https://nayoo.co/khonkaen/posts/21
# ..             ...                                   ...
# 195              2  https://nayoo.co/khonkaen/posts/7439
# 196              1  https://nayoo.co/khonkaen/posts/7668
# 197              2  https://nayoo.co/khonkaen/posts/7668
# 198              1  https://nayoo.co/khonkaen/posts/7705
# 199              2  https://nayoo.co/khonkaen/posts/7705
#
#              property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 1    อาคารพาณิชย์/สำนักงาน                        มั่นใจ     6600000
# 2    อาคารพาณิชย์/สำนักงาน                        มั่นใจ    11400000
# ...

# %% [markdown]
# #### mape

# %%
est1_commercial = commercial[commercial['ID ผู้ประเมิน']==1]
est1_commercial = est1_commercial.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_commercial = commercial[commercial['ID ผู้ประเมิน']==2]
est2_commercial = est2_commercial.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_commercial_mape = mean_absolute_percentage_error(est1_commercial['ราคาทรัพย์'],pd.to_numeric(est1_commercial['ประเมินราคาซื้อ-ขาย']))
est2_commercial_mape = mean_absolute_percentage_error(est2_commercial['ราคาทรัพย์'],pd.to_numeric(est2_commercial['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {est1_commercial_mape*100:.2f}%\nนักประเมิน คนที่ 2 = {est2_commercial_mape*100:.2f}%')
est2_commercial['ประเมิน1'] = est2_commercial['post id'].map(est1_commercial.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_commercial_new = est2_commercial.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
est2_commercial_new = est2_commercial_new[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]
one2two = mean_absolute_percentage_error(est2_commercial_new['ประเมินราคาซื้อ-ขาย'],est2_commercial_new['ประเมิน1'])
two2one = mean_absolute_percentage_error(est2_commercial_new['ประเมิน1'],est2_commercial_new['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est2_commercial_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# อาคารพาณิชย์
# นักประเมิน คนที่ 1 = 13.23%
# นักประเมิน คนที่ 2 = 11.42%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.53%
# จำนวนทรัพย์ทั้งหมด 91 ทรัพย์

# %%
est2_commercial_new
# Out:
#                                   post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000            8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000           12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000           20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000            4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000            3000000.0
# ..                                    ...         ...                  ...
# 183  https://nayoo.co/khonkaen/posts/6168     2652000            2700000.0
# 185  https://nayoo.co/khonkaen/posts/6169     3851000            4000000.0
# 187  https://nayoo.co/khonkaen/posts/6176     3410000            3500000.0
# 191  https://nayoo.co/khonkaen/posts/7137     3900000            4000000.0
# 199  https://nayoo.co/khonkaen/posts/7705     2200000            2000000.0
#
#        ประเมิน1
# 1     6000000.0
# 3    12000000.0
# ...

# %% [markdown]
# ## ตรวจสอบค่าที่เติม 0 ผิด

# %% [markdown]
# ### บ้าน

# %%
#est2_home_new.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'}, inplace=True)

# %%
est2_home_new
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000            2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000            2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000            9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000            3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000            2500000.0
# ...                                    ...         ...                  ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000             300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000             500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000             300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000             500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000             700000.0
#
#        ประเมิน1
# 1     2500000.0
# 3     2200000.0
# ...

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)
#est2_home_new['check2']=est2_home_new.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)

# %%
check1 = list()
for row in est2_home_new.iterrows():
     check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check2 = list()
for row in est2_home_new.iterrows():
     check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินราคาซื้อ-ขาย']))

# %%
est2_home_new['check1'] = check1
est2_home_new['check2'] = check2
est2_home_new
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000            2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000            2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000            9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000            3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000            2500000.0
# ...                                    ...         ...                  ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000             300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000             500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000             300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000             500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000             700000.0
#
#        ประเมิน1    check1    check2
# ...

# %%
est2_home_new.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 802   https://nayoo.co/khonkaen/posts/3208    23900000            2200000.0
# 1070  https://nayoo.co/khonkaen/posts/6037     1450000            3000000.0
# 228    https://nayoo.co/khonkaen/posts/525     1933000            2200000.0
# 1210  https://nayoo.co/khonkaen/posts/6255      260000             300000.0
# 767   https://nayoo.co/khonkaen/posts/2321      465000             400000.0
# ...                                    ...         ...                  ...
# 266    https://nayoo.co/khonkaen/posts/585     3300000            3500000.0
# 63    https://nayoo.co/khonkaen/posts/2033     1200000            1000000.0
# 652   https://nayoo.co/khonkaen/posts/2256     2000000            2200000.0
# 43    https://nayoo.co/khonkaen/posts/1128     4200000            5000000.0
# 928   https://nayoo.co/khonkaen/posts/3819     2500000            2900000.0
#
#        ประเมิน1     check1     check2
# ...

# %%
est2_home_new.sort_values(by=['check2'],ascending=False)
# Out:
#                                     post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 802    https://nayoo.co/khonkaen/posts/3208    23900000            2200000.0
# 544    https://nayoo.co/khonkaen/posts/1619     2850000           29000000.0
# 292     https://nayoo.co/khonkaen/posts/622     8019000           80000000.0
# 75        https://nayoo.co/khonkaen/posts/1      390000            1300000.0
# 1070   https://nayoo.co/khonkaen/posts/6037     1450000            3000000.0
# ...                                     ...         ...                  ...
# 806    https://nayoo.co/khonkaen/posts/3210     2390000            2390000.0
# 169   https://nayoo.co/khonkaen/posts/11264     6500000            6500000.0
# 763    https://nayoo.co/khonkaen/posts/2319     1200000            1200000.0
# 1149   https://nayoo.co/khonkaen/posts/6096     2200000            2200000.0
# 564    https://nayoo.co/khonkaen/posts/1834     1700000            1700000.0
#
#        ประเมิน1     check1     check2
# ...

# %%
#est2_home_new.drop(est2_home_new[(est2_home_new['check1'] >8) & (est2_home_new['check2'] >8 )].index, inplace=True)

# %% [markdown]
# ### ที่ดิน

# %%
est2_land_new
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000            2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000           12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000           70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000           60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000            2500000.0
# ..                                     ...         ...                  ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000            4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000             750000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000            2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000            1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000            2800000.0
#
#        ประเมิน1
# 1     1800000.0
# 4     8000000.0
# ...

# %%
check1 = list()
for row in est2_land_new.iterrows():
     check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check2 = list()
for row in est2_land_new.iterrows():
     check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินราคาซื้อ-ขาย']))

# %%
est2_land_new['check1'] = check1
est2_land_new['check2'] = check2
est2_land_new
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000            2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000           12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000           70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000           60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000            2500000.0
# ..                                     ...         ...                  ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000            4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000             750000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000            2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000            1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000            2800000.0
#
#        ประเมิน1    check1    check2
# ...

# %%
est2_land_new.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000           75000000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000            2000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000           18000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   120000000           11000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000           70000000.0
# ..                                     ...         ...                  ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000            4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000             800000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000            1200000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000             700000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000            2200000.0
#
#        ประเมิน1     check1     check2
# ...

# %%
est2_land_new.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 47    https://nayoo.co/khonkaen/posts/7349   245000000           18000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   120000000           11000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550           80000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000           24000000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000            9000000.0
# ..                                     ...         ...                  ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000            8000000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000            8000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000             750000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000            3500000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000           14000000.0
#
#        ประเมิน1     check1     check2
# ...

# %%
#est2_land_new.drop(est2_land_new[(est2_land_new['check1'] >8) & (est2_land_new['check2'] >8 )].index, inplace=True)

# %% [markdown]
# ### คอนโด

# %%
est1_condo_new
# Out:
#    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# 0     32.0     3500000            3500000.0
# 1     36.0     1930000            2200000.0
# 2    603.0     2438000            2800000.0
# 3   1395.0     1600000            2300000.0
# 4   1443.0     1860000            1800000.0
# 5   1609.0     1490000            1500000.0
# 6   1640.0     1280000            1600000.0
# 7   1641.0     4290000            2700000.0
# 8   1650.0     1700000            1550000.0
# 9   1840.0     3790000            2800000.0

# %%
check1 = list()
for row in est1_condo_new.iterrows():
     check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินราคาซื้อ-ขาย']))

# %%
est1_condo_new['check1'] = check1
est1_condo_new
# Out:
# <ipython-input-116-dc039dd109c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est1_condo_new['check1'] = check1
#    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย    check1
# 0     32.0     3500000            3500000.0  1.000000
# 1     36.0     1930000            2200000.0  1.139896
# 2    603.0     2438000            2800000.0  1.148482
# 3   1395.0     1600000            2300000.0  1.437500
# 4   1443.0     1860000            1800000.0  1.033333
# 5   1609.0     1490000            1500000.0  1.006711
# 6   1640.0     1280000            1600000.0  1.250000
# 7   1641.0     4290000            2700000.0  1.588889
# 8   1650.0     1700000            1550000.0  1.096774
# 9   1840.0     3790000            2800000.0  1.353571

# %% [markdown]
# ### ทาวน์โฮม

# %%
est2_townhome_new
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000            1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000            1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000            4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000            3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000             800000.0
# ..                                     ...         ...                  ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000            1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000            1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000            1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000            1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000            1700000.0
#
#       ประเมิน1
# 1     700000.0
# 3     700000.0
# ...

# %%
check1 = list()
for row in est2_townhome_new.iterrows():
     check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check2 = list()
for row in est2_townhome_new.iterrows():
     check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินราคาซื้อ-ขาย']))

# %%
est2_townhome_new['check1'] = check1
est2_townhome_new['check2'] = check2
est2_townhome_new
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000            1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000            1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000            4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000            3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000             800000.0
# ..                                     ...         ...                  ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000            1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000            1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000            1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000            1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000            1700000.0
#
#       ประเมิน1    check1    check2
# ...

# %%
est2_townhome_new.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 176   https://nayoo.co/khonkaen/posts/3528     2190000             400000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000             800000.0
# 206  https://nayoo.co/khonkaen/posts/17507     1085000             700000.0
# 216  https://nayoo.co/khonkaen/posts/17535      840000            1000000.0
# 1      https://nayoo.co/khonkaen/posts/548     1045000            1500000.0
# ..                                     ...         ...                  ...
# 162   https://nayoo.co/khonkaen/posts/2242     1610000            1600000.0
# 228  https://nayoo.co/khonkaen/posts/17923     1990000            2200000.0
# 167   https://nayoo.co/khonkaen/posts/2829     2490000            2300000.0
# 200  https://nayoo.co/khonkaen/posts/13411     3200000            3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503     1500000            1300000.0
#
#       ประเมิน1    check1    check2
# ...

# %%
est2_townhome_new.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 176   https://nayoo.co/khonkaen/posts/3528     2190000             400000.0
# 234  https://nayoo.co/khonkaen/posts/18090     2850000            1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000            1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000            4000000.0
# 206  https://nayoo.co/khonkaen/posts/17507     1085000             700000.0
# ..                                     ...         ...                  ...
# 202  https://nayoo.co/khonkaen/posts/15111     2200000            2200000.0
# 209  https://nayoo.co/khonkaen/posts/17511     1700000            1700000.0
# 212  https://nayoo.co/khonkaen/posts/17516     1800000            1800000.0
# 213  https://nayoo.co/khonkaen/posts/17518     1200000            1200000.0
# 152   https://nayoo.co/khonkaen/posts/2011     1100000            1100000.0
#
#       ประเมิน1    check1    check2
# ...

# %% [markdown]
# ### อาคารพาณิชย์

# %%
est2_commercial_new
# Out:
#                                   post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000            8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000           12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000           20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000            4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000            3000000.0
# ..                                    ...         ...                  ...
# 183  https://nayoo.co/khonkaen/posts/6168     2652000            2700000.0
# 185  https://nayoo.co/khonkaen/posts/6169     3851000            4000000.0
# 187  https://nayoo.co/khonkaen/posts/6176     3410000            3500000.0
# 191  https://nayoo.co/khonkaen/posts/7137     3900000            4000000.0
# 199  https://nayoo.co/khonkaen/posts/7705     2200000            2000000.0
#
#        ประเมิน1
# 1     6000000.0
# 3    12000000.0
# ...

# %%
check1 = list()
for row in est2_commercial_new.iterrows():
     check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
check2 = list()
for row in est2_commercial_new.iterrows():
     check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินราคาซื้อ-ขาย']))

# %%
est2_commercial_new['check1'] = check1
est2_commercial_new['check2'] = check2
est2_commercial_new
# Out:
#                                   post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000            8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000           12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000           20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000            4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000            3000000.0
# ..                                    ...         ...                  ...
# 183  https://nayoo.co/khonkaen/posts/6168     2652000            2700000.0
# 185  https://nayoo.co/khonkaen/posts/6169     3851000            4000000.0
# 187  https://nayoo.co/khonkaen/posts/6176     3410000            3500000.0
# 191  https://nayoo.co/khonkaen/posts/7137     3900000            4000000.0
# 199  https://nayoo.co/khonkaen/posts/7705     2200000            2000000.0
#
#        ประเมิน1    check1    check2
# ...

# %%
est2_commercial_new.sort_values(by=['check1'],ascending=False)
# Out:
#                                   post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 9      https://nayoo.co/khonkaen/posts/24     3900000            3000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000           20000000.0
# 169  https://nayoo.co/khonkaen/posts/6043     2240000            3000000.0
# 87    https://nayoo.co/khonkaen/posts/707     1450000            3200000.0
# 81    https://nayoo.co/khonkaen/posts/701     1925000            2000000.0
# ..                                    ...         ...                  ...
# 61    https://nayoo.co/khonkaen/posts/643     4180000            4200000.0
# 65    https://nayoo.co/khonkaen/posts/651     2200000            2000000.0
# 161  https://nayoo.co/khonkaen/posts/5995     3000000            6000000.0
# 177  https://nayoo.co/khonkaen/posts/6123     2200000            2200000.0
# 17    https://nayoo.co/khonkaen/posts/498     7000000            8000000.0
#
#        ประเมิน1    check1    check2
# ...

# %%
est2_commercial_new.sort_values(by=['check2'],ascending=False)
# Out:
#                                   post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 163  https://nayoo.co/khonkaen/posts/6009     2250000            5000000.0
# 87    https://nayoo.co/khonkaen/posts/707     1450000            3200000.0
# 161  https://nayoo.co/khonkaen/posts/5995     3000000            6000000.0
# 49    https://nayoo.co/khonkaen/posts/602     2520000            3500000.0
# 169  https://nayoo.co/khonkaen/posts/6043     2240000            3000000.0
# ..                                    ...         ...                  ...
# 121  https://nayoo.co/khonkaen/posts/2180     5000000            5000000.0
# 109  https://nayoo.co/khonkaen/posts/1885     3500000            3500000.0
# 107  https://nayoo.co/khonkaen/posts/1858     1500000            1500000.0
# 101  https://nayoo.co/khonkaen/posts/1614     2500000            2500000.0
# 127  https://nayoo.co/khonkaen/posts/2247     1900000            1900000.0
#
#       ประเมิน1    check1    check2
# ...

# %% [markdown]
# ##  ค่าMAPEหลังจากแก้ไขข้อมูล

# %% [markdown]
# ### บ้าน

# %%
link = 'https://docs.google.com/spreadsheets/d/1DO2EP-hfqV-FI2bpOTP1nVESYixq9QuP5pvq_Kq6NT8/export?format=xlsx'
home2 = pd.read_excel(link,sheet_name='home')
home2
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1213              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1214              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1215              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #### mape

# %%
est1_home2 = home2[home2['ID ผู้ประเมิน']==1]
est1_home2 = est1_home2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_home2 = home2 [home2 ['ID ผู้ประเมิน']==2]
est2_home2 = est2_home2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_home2_mape = mean_absolute_percentage_error(est1_home2['ราคาทรัพย์'],pd.to_numeric(est1_home2['ประเมินราคาซื้อ-ขาย']))
est2_home2_mape = mean_absolute_percentage_error(est2_home2['ราคาทรัพย์'],pd.to_numeric(est2_home2['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {est1_home2_mape*100:.2f}%\nนักประเมิน คนที่ 2 = {est2_home2_mape*100:.2f}%')
est2_home2['ประเมิน1'] = est2_home2['post id'].map(est1_home2.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_home2_new = est2_home2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
est2_home2_new = est2_home2_new[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]
one2two = mean_absolute_percentage_error(est2_home2_new['ประเมินราคาซื้อ-ขาย'],est2_home2_new['ประเมิน1'])
two2one = mean_absolute_percentage_error(est2_home2_new['ประเมิน1'],est2_home2_new['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est2_home2_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 12.65%
# นักประเมิน คนที่ 2 = 10.07%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.45%
# จำนวนทรัพย์ทั้งหมด 497 ทรัพย์

# %% [markdown]
# ### ที่ดิน

# %%
link = 'https://docs.google.com/spreadsheets/d/1DO2EP-hfqV-FI2bpOTP1nVESYixq9QuP5pvq_Kq6NT8/export?format=xlsx'
land2 = pd.read_excel(link,sheet_name='land')
land2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 201              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 203              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 205              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #### mape

# %%
est1_land2 = land2[land2['ID ผู้ประเมิน']==1]
est1_land2 = est1_land2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est2_land2 = land2[land2['ID ผู้ประเมิน']==2]
est2_land2 = est2_land2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
est1_land2_mape = mean_absolute_percentage_error(est1_land2['ราคาทรัพย์'],pd.to_numeric(est1_land2['ประเมินราคาซื้อ-ขาย']))
est2_land2_mape = mean_absolute_percentage_error(est2_land2['ราคาทรัพย์'],pd.to_numeric(est2_land2['ประเมินราคาซื้อ-ขาย']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {est1_land2_mape*100:.2f}%\nนักประเมิน คนที่ 2 = {est2_land2_mape*100:.2f}%')
est2_land2['ประเมิน1'] = est2_land2['post id'].map(est1_land2.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est2_land2_new = est2_land2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
est2_land2_new = est2_land2_new[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ประเมิน1']]
one2two = mean_absolute_percentage_error(est2_land2_new['ประเมินราคาซื้อ-ขาย'],est2_land2_new['ประเมิน1'])
two2one = mean_absolute_percentage_error(est2_land2_new['ประเมิน1'],est2_land2_new['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(est2_land2_new)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 28.08%
# นักประเมิน คนที่ 2 = 28.53%
# ความผิดพลาดระหว่างนักประเมินทั้ง 37.03%
# จำนวนทรัพย์ทั้งหมด 98 ทรัพย์

# %% [markdown]
# # HW3 visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
from matplotlib.pyplot import figure

# %%
#แสดงผลภาษาไทย
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
# !ls
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')
# Out:
# drive  gdrive  sample_data  thsarabunnew-webfont.ttf

# %%
est_list = [home2,land2,condo,townhome,commercial]  # List of your dataframes
all_est = pd.concat(est_list)
all_est.shape
all_est_old = all_est

# %%
all_est['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       1750
# ไม่มั่นใจ     124
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
#all_est.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'],inplace=True)

# %%
all_est1 = all_est[all_est['ID ผู้ประเมิน']==1]
all_est2 = all_est[all_est['ID ผู้ประเมิน']==2]

# %%
all_est1['property_type'].unique()
# Out:
# array(['บ้านเดี่ยว', 'บ้านแฝด', 'ที่ดิน', 'คอนโด', 'ทาวน์โฮม',
#        'อาคารพาณิชย์/สำนักงาน'], dtype=object)

# %%
all_est2['property_type'].unique()
# Out:
# array(['บ้านเดี่ยว', 'บ้านแฝด', 'ที่ดิน', 'ทาวน์โฮม',
#        'อาคารพาณิชย์/สำนักงาน'], dtype=object)

# %%
all_est.columns
# Out:
# Index(['ID ผู้ประเมิน', 'post id', 'property_type',
#        'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย',
#        'ปัจจัยในการประเมินราคาซื้อ-ขาย', 'เหตุผลไม่มั่นใจราคาประเมิน',
#        'ให้คะแนนทรัพย์', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12'],
#       dtype='object')

# %%
all = all_est[['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมินราคาซื้อ-ขาย',  'ให้คะแนนทรัพย์']]

# %% [markdown]
# ### parallel_coordinates ราคาทรัพย์กับราคาประเมิน

# %%
matplotlib.rcParams['figure.figsize']=[15,15]
plt.subplot(1,2,1)
pd.plotting.parallel_coordinates(all_est1, 'property_type',cols = ['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'], color=['#00FFFF', 'blue','red','pink','yellow','green'])

plt.subplot(1,2,2)
pd.plotting.parallel_coordinates(all_est2, 'property_type',cols = ['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'], color=['#00FFFF', 'blue','red','yellow','green'])

# %% [markdown]
# ## ความมั่นใจในการประเมิน

# %%
allc = all.groupby(['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์'])[['ความมั่นใจในการเมินราคาทรัพย์']].count().iloc[:2]

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.suptitle('ความมั่นใจในการประเมินราคาทรัพย์สินต่างๆ', fontsize = 20)

plt.barh([1,2],allc['ความมั่นใจในการเมินราคาทรัพย์'],color=['#ffcce0','#ffccff']) 
plt.yticks([1,2],['est1','est2'])
plt.title('Home')
# Out:
# Text(0.5, 1.0, 'Home')

# %%
all_est_score = all_est.pivot_table('post id',index='property_type',columns='ให้คะแนนทรัพย์',aggfunc='count').reset_index().fillna(0)
matplotlib.rcParams['figure.figsize']=[10,10]
name = all_est_score.reset_index()['property_type']
aaa = all_est_score['1 ขายไม่ได้แน่นอน']
bbb = all_est_score['2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี']
ccc = all_est_score['3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน']
ddd = all_est_score['4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน']
eee = all_est_score['5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน']
figure(figsize=(15,15), dpi=70)
x = np.arange(len(aaa))
x2=x
w=0.2
plt.bar(x,aaa,width=w,color='pink',label='1 ขายไม่ได้แน่นอน')
x=x+w
plt.bar(x,bbb,width=w,color='powderblue',alpha = 0.9,label='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี')
x=x+w
plt.bar(x,ccc,width=w,color='plum',alpha = 0.72,label='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน')
x=x+w
plt.bar(x,ddd,width=w,color='lightgreen',alpha = 0.9,label='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน')
x=x+w
plt.bar(x,eee,width=w,color='silver',alpha = 0.9,label='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน')

plt.xticks(x2+(w+(w/2)),name,rotation=0)
plt.legend();

# %% [markdown]
# ## ความสัมพันธ์ระหว่างราคาตั้งขาย ราคาประเมิน ความมั่นใจและการให้คะแนนทรัพย์

# %%
plt.rcParams['figure.figsize']=[28,8]
plt.suptitle('ราคาทรัพย์และการประเมินราคา', fontsize = 20)

plt.plot(all['ราคาทรัพย์'], linestyle='-', linewidth=7, color='royalblue', label='ราคาทรัพย์')
plt.plot(all_est1['ประเมินราคาซื้อ-ขาย'], linestyle='-', linewidth=5 , color='lightcoral', label='นักประเมินคนที่ 1')
plt.plot(all_est2['ประเมินราคาซื้อ-ขาย'], linestyle='-',linewidth=2 , color='yellowgreen',  label='นักประเมินคนที่ 2')
plt.title('Home')
# Out:
# Text(0.5, 1.0, 'Home')

# %%
plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title("ความสัมพันธ์ระหว่างราคาทรัพย์และราคาประเมินซื้อขาย")
sns.regplot(x="ราคาทรัพย์", y="ประเมินราคาซื้อ-ขาย", data=all_est)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.relplot(data=all_est, x="ราคาทรัพย์", y="ประเมินราคาซื้อ-ขาย", hue="ให้คะแนนทรัพย์",style="ความมั่นใจในการเมินราคาทรัพย์",sizes=(150, 150),size="ให้คะแนนทรัพย์" ,palette="ch:s=-.2,r=.6")
