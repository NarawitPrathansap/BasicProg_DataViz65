# %% [markdown]
# <a href="https://colab.research.google.com/github/NarawitPrathansap/BasicProg_DataViz65/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')
data
# Out:
#        row_number               unittype_id                project_id  \
# 0           27501             unittype_9565              project_2446
# 1           28777            unittype_10267              project_3543
# 2           28865              unittype_471               project_143
# 3           24988            unittype_19506              project_7766
# 4           38596            unittype_10290              project_3551
# ...           ...                       ...                       ...
# 42620       37109            unittype_38508             project_16864
# 42621          14            unittype_14016              project_5275
# 42622       41009  617bde1687dd2300149d2195  617bdd47f62011001350de07
# 42623        9333            unittype_37375             project_16389
# 42624         780            unittype_17011              project_6762
#
#                    name_th  propertytype_id propertytype_name_en  \
# ...

# %%
set(unit['propertytype_name_en'])#ตรวจสอบค่าในcolumn
# Out:
# {'Apartment',
#  'Commercial',
#  'Condo',
#  'Detached House',
#  'Home office',
#  'Hotel',
#  'Land',
#  'Office Space',
#  'Townhome',
#  'Twin house',
#  'Warehouse / Factory'}

# %%
Condo_unit = data[data['propertytype_name_en']=='Condo']
Condo_unit.head()
# Out:
#     row_number     unittype_id     project_id           name_th  \
# 0        27501   unittype_9565   project_2446         2 Bedroom
# 2        28865    unittype_471    project_143  1 Bedroom Type B
# 3        24988  unittype_19506   project_7766  Studio Floor 1-2
# 10        5238  unittype_15162   project_4107  Studio Floor 5-8
# 14       29911  unittype_25780  project_10313         1 Bedroom
#
#     propertytype_id propertytype_name_en propertytype_name_th  \
# 0                 2                Condo                คอนโด
# 2                 2                Condo                คอนโด
# 3                 2                Condo                คอนโด
# 10                2                Condo                คอนโด
# 14                2                Condo                คอนโด
#
#     area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                 NaN             37.3  2500000.0  ...               1.0
# ...

# %%
Townhome_unit = data[data['propertytype_name_en']=='Townhome']
Townhome_unit.head()
# Out:
#     row_number               unittype_id     project_id          name_th  \
# 4        38596            unittype_10290   project_3551             TH 3
# 12       26883            unittype_22911   project_8692           Type B
# 13       40751  61516ba1cd39f40018537c6d   project_3391             HAUS
# 15       30642            unittype_28034  project_11464  ทาวน์โฮมสองชั้น
# 42       38678            unittype_27892  project_11388  ทาวน์โฮมสองชั้น
#
#     propertytype_id propertytype_name_en propertytype_name_th  \
# 4                 3             Townhome             ทาวน์โฮม
# 12                3             Townhome             ทาวน์โฮม
# 13                3             Townhome             ทาวน์โฮม
# 15                3             Townhome             ทาวน์โฮม
# 42                3             Townhome             ทาวน์โฮม
#
#     area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 4                 NaN            182.0  2390000.0  ...               1.0
# ...

# %%
data_2 = pd.concat([Townhome_unit,Condo_unit])
data_2
# Out:
#        row_number               unittype_id     project_id  \
# 4           38596            unittype_10290   project_3551
# 12          26883            unittype_22911   project_8692
# 13          40751  61516ba1cd39f40018537c6d   project_3391
# 15          30642            unittype_28034  project_11464
# 42          38678            unittype_27892  project_11388
# ...           ...                       ...            ...
# 42590       23548            unittype_15279   project_3976
# 42602       39384             unittype_3476    project_812
# 42604        1058             unittype_7949   project_2641
# 42607       13546            unittype_40152  project_17505
# 42615       36172            unittype_34140  project_14663
#
#                            name_th  propertytype_id propertytype_name_en  \
# 4                             TH 3                3             Townhome
# 12                          Type B                3             Townhome
# ...

# %%
Condo_unit2 = data[data['propertytype_name_en']=='Condo'][['area_usable_min','price_min']]
Condo_unit2.head()
# Out:
#     area_usable_min  price_min
# 0              37.3  2500000.0
# 2              28.0        NaN
# 3              27.0   170000.0
# 10             30.0  1116000.0
# 14             50.0  1700000.0

# %%
Townhome_unit2 = data[data['propertytype_name_en']=='Townhome'][['area_usable_min','price_min']]
Townhome_unit2.head()
# Out:
#     area_usable_min  price_min
# 4             182.0  2390000.0
# 12              NaN        NaN
# 13            125.0        NaN
# 15            134.0  1590000.0
# 42            144.0  2680000.0

# %%
pd.concat([Townhome_unit2,Condo_unit2])
# Out:
#        area_usable_min   price_min
# 4                182.0   2390000.0
# 12                 NaN         NaN
# 13               125.0         NaN
# 15               134.0   1590000.0
# 42               144.0   2680000.0
# ...                ...         ...
# 42590             33.0    989000.0
# 42602             94.0   6345000.0
# 42604             34.0   3120000.0
# 42607             71.0  17000000.0
# 42615             60.0   3500000.0
#
# [20827 rows x 2 columns]

# %%
data.isnull()
# Out:
#        row_number  unittype_id  project_id  name_th  propertytype_id  \
# 0           False        False       False    False            False
# 1           False        False       False    False            False
# 2           False        False       False    False            False
# 3           False        False       False    False            False
# 4           False        False       False    False            False
# ...           ...          ...         ...      ...              ...
# 42620       False        False       False    False            False
# 42621       False        False       False    False            False
# 42622       False        False       False    False            False
# 42623       False        False       False    False            False
# 42624       False        False       False    False            False
#
#        propertytype_name_en  propertytype_name_th  area_total_min_wa  \
# ...

# %%
data.dropna(subset=['area_total_min_wa']).isnull().any()
# Out:
# row_number              False
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_id         False
# propertytype_name_en    False
# propertytype_name_th    False
# area_total_min_wa       False
# area_usable_min          True
# price_min                True
# count_airconditioner     True
# count_elevator           True
# count_floor_internal     True
# count_parking            True
# count_room_bath          True
# count_room_bed           True
# count_room_dinning       True
# count_room_guest         True
# count_room_kitchen       True
# count_room_living        True
# count_room_maid          True
# count_room_storage       True
# count_room_utility       True
# date_created            False
# date_updated            False
# source                  False
# url_unittype            False
# dtype: bool

# %% [markdown]
# # วนลูปตารางในrecord

# %%
data_x = data[['propertytype_name_en','area_usable_min','price_min']]
data_x
# Out:
#       propertytype_name_en  area_usable_min  price_min
# 0                    Condo             37.3  2500000.0
# 1               Twin house            150.0  2390000.0
# 2                    Condo             28.0        NaN
# 3                    Condo             27.0   170000.0
# 4                 Townhome            182.0  2390000.0
# ...                    ...              ...        ...
# 42620       Detached House            157.0        NaN
# 42621       Detached House            223.0  7490000.0
# 42622             Townhome            133.0        NaN
# 42623       Detached House            180.0  3200000.0
# 42624       Detached House            170.0  3790000.0
#
# [42625 rows x 3 columns]

# %%
for each_row in data_x.iterrows():
    # print(each_row)
    # print(each_row[1])
    # print(each_row[1]['sex'])
    if (each_row[1]['price_min'] > 500000) and (each_row[1]['propertytype_name_en'] == 'Condo'):
        print(each_row)
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# (37319, propertytype_name_en        Condo
# area_usable_min              51.0
# price_min               4700000.0
# Name: 37319, dtype: object)
# (37320, propertytype_name_en        Condo
# area_usable_min              35.0
# price_min               1200000.0
# Name: 37320, dtype: object)
# (37330, propertytype_name_en        Condo
# area_usable_min              56.0
# price_min               3031000.0
# Name: 37330, dtype: object)
# (37331, propertytype_name_en        Condo
# area_usable_min              33.0
# price_min               1990000.0
# Name: 37331, dtype: object)
# (37333, propertytype_name_en        Condo
# area_usable_min              31.0
# price_min               1304000.0
# Name: 37333, dtype: object)
# (37340, propertytype_name_en        Condo
# area_usable_min              69.0
# price_min               4500000.0
# Name: 37340, dtype: object)
# (37346, propertytype_name_en        Condo
# ...

# %%
data1 = data.dropna(subset=['propertytype_name_en','price_min','area_usable_min'])

# %%
maxprice = data1.groupby('propertytype_name_en')[['price_min','area_total_min_wa' , 'area_usable_min', 'count_room_bed']].max().reset_index()
maxprice
# Out:
#   propertytype_name_en    price_min  area_total_min_wa  area_usable_min  \
# 0            Apartment    2370000.0                NaN            40.00
# 1           Commercial   52000000.0               60.0          1360.00
# 2                Condo  580000000.0                NaN          4350.00
# 3       Detached House  285000000.0              335.0          2548.00
# 4          Home office   92000000.0               73.6          1065.00
# 5                Hotel   27300000.0                NaN           120.00
# 6         Office Space   25000000.0                NaN           585.00
# 7             Townhome  120000000.0               65.2          1000.00
# 8           Twin house  129000000.0               96.5           724.95
# 9  Warehouse / Factory   29200000.0                NaN           970.00
#
#    count_room_bed
# 0             1.0
# 1            10.0
# 2             6.0
# 3            10.0
# 4            10.0
# 5             2.0
# 6             4.0
# 7            10.0
# ...

# %%
for row in maxprice.iterrows():
    print(row[1]['propertytype_name_en'],row[1]['price_min'])
    print(data1[(data1['propertytype_name_en']==row[1]['propertytype_name_en']) & (data1['price_min']==row[1]['price_min'])][['area_total_min_wa' , 'area_usable_min', 'count_room_bed']])
# Out:
# Apartment 2370000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# 36707                NaN             32.0             1.0
# Commercial 52000000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# 10190                NaN           1065.0             7.0
# Condo 580000000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# 33122                NaN           1182.0             3.0
# Detached House 285000000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# 18443                NaN           2400.0             5.0
# Home office 92000000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# 39868                NaN            856.0             NaN
# Hotel 27300000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# 32899                NaN            120.0             2.0
# Office Space 25000000.0
#        area_total_min_wa  area_usable_min  count_room_bed
# ...
